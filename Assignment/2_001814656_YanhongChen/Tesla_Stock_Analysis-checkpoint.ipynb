# %% [markdown]
# <div style="text-align: right">INFO 6105 Assignment 2 </div>
# <div style="text-align: right">NUID: 001814656 NAME: Yanhong Chen</div>
# <div style="text-align: right">NUID: 001083355 NAME: Hao Dong </div>

# %% [markdown]
# Study the stationarity of three stocks from three different industries.
#
# Plot closing prices, model them with either simple or double exponential smoothing, and test to see if they're stationary.
#
# Use a random forest from Scikit-learn to predict stock prices for your three chosen stocks, and see how far into the future you can go.
#
# What to submit: readme, code, and dataset of your choice.
#
# Note: Please include your team information in the readme file.

# %% [markdown]
# <b>Tesla Stock Historical Data (TSLA)</b>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

data = pd.read_csv('data/Tesla_Historical_Data.csv', index_col=['Date'], parse_dates=['Date'])
### print(data.columns)
data = data.rename(columns={' Close': 'Close'})
data.head(20)
# Out:
#              Close    Volume    Open    High     Low
# Date
# 2020-01-17  510.50  13629070  507.61  515.67  503.16
# 2020-01-16  513.49  21736650  493.75  514.46  492.17
# 2020-01-15  518.50  17368830  529.76  537.84  516.79
# 2020-01-14  537.92  29061380  544.26  547.41  524.90
# 2020-01-13  524.86  26634550  493.50  525.63  492.00
# 2020-01-10  478.15  12976830  481.79  484.94  473.70
# 2020-01-09  481.34  28463190  497.10  498.80  472.87
# 2020-01-08  492.14  31199390  473.70  498.49  468.23
# 2020-01-07  469.06  18209140  461.40  471.63  453.36
# 2020-01-06  451.54  10157500  440.47  451.56  440.00
# 2020-01-03  443.01  17794700  440.50  454.00  436.92
# 2020-01-02  430.26   9558386  424.50  430.70  421.71
# 2019-12-31  418.33  10292460  405.00  421.29  402.08
# 2019-12-30  414.70  12601270  428.79  429.00  409.26
# 2019-12-27  430.38   9956827  435.00  435.31  426.11
# 2019-12-26  430.94  10648290  427.91  433.48  426.35
# 2019-12-24  425.25   8054720  418.36  425.47  412.69
# 2019-12-23  419.22  13332820  411.78  422.01  410.00
# 2019-12-20  405.59  14785210  410.29  413.00  400.19
# 2019-12-19  404.04  18120310  397.32  406.85  396.50

# %%
plt.figure(figsize=(18, 8))
plt.plot(data.Close)
plt.title('Closing price of Tesla(TSLA)')
plt.ylabel('Closing price ($)')
plt.xlabel('Trading day')
plt.grid(True)
plt.show()

# %% [markdown]
# Moving average

# %%
from sklearn.metrics import mean_absolute_error

def plot_moving_average(series, window, plot_intervals=False, scale=1.96):
    rolling_mean = series.rolling(window=window).mean()
 
    plt.figure(figsize=(17,8))
    plt.title('Moving average\n window size = {}'.format(window))
    plt.plot(rolling_mean, 'g', label='Rolling mean trend')

    #Plot confidence intervals for smoothed values
    if plot_intervals:
        mae = mean_absolute_error(series[window:], rolling_mean[window:])
        deviation = np.std(series[window:] - rolling_mean[window:])
        lower_bound = rolling_mean - (mae + scale * deviation)
        upper_bound = rolling_mean + (mae + scale * deviation)
        plt.plot(upper_bound, 'r--', label='Upper bound / Lower bound')
        plt.plot(lower_bound, 'r--')

    plt.plot(series[window:], label='Actual values')
    plt.legend(loc='best')
    plt.grid(True)


#Smooth by previous quarter (30 days)
plot_moving_average(data.Close, 30, plot_intervals=True)

# %% [markdown]
# Base on the graph, this trend of stock show a upward curve at the end. This might means that the stock is likely to go up in the following days.

# %% [markdown]
# ### Exponential smoothing
# **Simple exponential smoothing**
# Do exponential smoothing and use 0.08 and 0.5 as values for the smoothing factor.

# %%
def exponential_smoothing(series, alpha):
    result = [series[0]] # first value is same as series
    for n in range(1, len(series)):
        result.append(alpha * series[n] + (1 - alpha) * result[n-1])
    return result

def plot_exponential_smoothing(series, alphas):
    plt.figure(figsize=(17, 8))
    for alpha in alphas:
        plt.plot(exponential_smoothing(series, alpha), label="Alpha {}".format(alpha))
    plt.plot(series.values, "c", label = "Actual")
    plt.legend(loc="best")
    plt.axis('tight')
    plt.title("Exponential Smoothing")
    plt.grid(True);
        
plot_exponential_smoothing(data.Close, [0.08, 0.5])

# %% [markdown]
# **Double exponential smoothing**

# %%
def double_exponential_smoothing(series, alpha, beta):
    result = [series[0]]
    
    for n in range(1, len(series)+1):
        if n == 1:
            level, trend = series[0], series[1] - series[0]
        if n >= len(series): # forecasting
            value = result[-1]
        else:
            value = series[n]
        
        last_level, level = level, alpha * value + (1 - alpha) * (level + trend)
        trend = beta * (level - last_level) + (1 - beta) * trend
        result.append(level + trend)
    return result

def plot_double_exponential_smoothing(series, alphas, betas):
    plt.figure(figsize=(17, 8))
    for alpha in alphas:
        for beta in betas:
            plt.plot(double_exponential_smoothing(series, alpha, beta), label="Alpha {}, beta {}".format(alpha, beta))
    plt.plot(series.values, label = "Actual")
    plt.legend(loc="best")
    plt.axis('tight')
    plt.title("Double Exponential Smoothing")
    plt.grid(True)

plot_double_exponential_smoothing(data.Close, alphas=[0.9, 0.02], betas=[0.9, 0.02])

# %% [markdown]
# Base on the graph, this Double exponential smoothing trend of stock shows a little bit downward curve at the end. This might means that the stock is likely to go down in the following days after a period extraordinary rise.

# %% [markdown]
# ### Modelling
#
# Turn our series into a **stationary process** in order to model it. we appling the Dickey-Fuller test to see if it is a stationary process. <br>
#
# The Dickey-Fuller test is a point estimate, when it is tiny (say less than 0.01), we can safely say that the time series is stationary. Otherwise, *not*.

# %%
import statsmodels.api as sm
import statsmodels as smt

def tsplot(y, lags=None, figsize=(12, 7), syle='bmh'):
    
    if not isinstance(y, pd.Series):
        y = pd.Series(y)
        
    with plt.style.context(style='bmh'):
        fig = plt.figure(figsize=figsize)
        layout = (2,2)
        ts_ax = plt.subplot2grid(layout, (0,0), colspan=2)
        acf_ax = plt.subplot2grid(layout, (1,0))
        pacf_ax = plt.subplot2grid(layout, (1,1))
        
        y.plot(ax=ts_ax)
        p_value = sm.tsa.stattools.adfuller(y)[1]
        ts_ax.set_title('Time Series Analysis Plots\n Dickey-Fuller: p={0:.5f}'.format(p_value))
        smt.graphics.tsaplots.plot_acf(y, lags=lags, ax=acf_ax)
        smt.graphics.tsaplots.plot_pacf(y, lags=lags, ax=pacf_ax)
        plt.tight_layout()
        
tsplot(data.Close, lags=30)

# %% [markdown]
# Conclusion: By the Dickey-Fuller test, the time series is stationary because the Dickey-Fuller point is 0.00270, it's less than 0.01.

# %% [markdown]
# ### Using random forest from Scikit-learn to predict stock prices

# %%
data = pd.read_csv('data/Tesla_Historical_Data.csv', parse_dates=[0])
data.head()
# Out:
#         Date   Close   Volume    Open    High     Low
# 0 2015-01-20  191.93  4490681  193.87  194.12  187.04
# 1 2015-01-21  196.57  4144121  189.55  198.68  189.51
# 2 2015-01-22  201.62  4103753  197.00  203.24  195.20
# 3 2015-01-23  201.29  3441052  200.29  203.50  198.33
# 4 2015-01-26  206.55  3231121  201.83  208.62  201.05

# %%
### Data transformations
data.columns = [x.strip() for x in data.columns]## strip() using for remove white space on the both side of string.
data.columns = [x.replace(' ', '_') for x in data.columns] ## remove white space
data.head()
# Out:
#         Date   Close   Volume    Open    High     Low
# 0 2015-01-20  191.93  4490681  193.87  194.12  187.04
# 1 2015-01-21  196.57  4144121  189.55  198.68  189.51
# 2 2015-01-22  201.62  4103753  197.00  203.24  195.20
# 3 2015-01-23  201.29  3441052  200.29  203.50  198.33
# 4 2015-01-26  206.55  3231121  201.83  208.62  201.05

# %% [markdown]
# Let's see if we can predict Close (y) from the other columns (X).
#
# Any column we want to predict is a y (dependent variable).
# The coluumns that help us predict it are x's (independent variables).
# And we useing a capital X to denote that there are many such columns.
#
# We will train a Random Forest with a sample of our data, then test it with another sample to see how it performs

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn import metrics
from sklearn.model_selection import train_test_split

# %%
### sorting data from previous to present
SortedData = data.sort_values(by = 'Date')
SortedData.head(30)
### export_csv = SortedData.to_csv (r'export_dataframe.csv', index = None, header=True)
# Out:
#          Date   Close    Volume    Open    High     Low
# 0  2015-01-20  191.93   4490681  193.87  194.12  187.04
# 1  2015-01-21  196.57   4144121  189.55  198.68  189.51
# 2  2015-01-22  201.62   4103753  197.00  203.24  195.20
# 3  2015-01-23  201.29   3441052  200.29  203.50  198.33
# 4  2015-01-26  206.55   3231121  201.83  208.62  201.05
# 5  2015-01-27  205.98   2777926  204.42  208.03  203.30
# 6  2015-01-28  199.37   3139481  206.11  206.37  198.42
# 7  2015-01-29  205.20   3542577  201.07  205.98  196.50
# 8  2015-01-30  203.60   3001268  203.96  207.47  203.00
# 9  2015-02-02  210.94   4143850  203.97  211.95  203.30
# 10 2015-02-03  218.36   4815834  213.22  220.37  211.27
# 11 2015-02-04  218.55   3304417  218.29  221.48  216.80
# 12 2015-02-05  220.99   3518316  219.88  225.48  219.64
# 13 2015-02-06  217.36   3235856  222.00  223.40  216.50
# 14 2015-02-09  217.48   3469776  215.38  217.93  211.99
# 15 2015-02-10  216.29   5348862  217.55  220.50  215.00
# 16 2015-02-11  212.80   9053083  212.21  214.74  207.28
# 17 2015-02-12  202.88  15626830  193.57  203.09  193.28
# 18 2015-02-13  203.77   6148207  202.90  205.99  200.91
# 19 2015-02-17  204.35   3964555  205.70  205.70  201.50
# 20 2015-02-18  204.46   2710898  204.17  206.17  202.60
# 21 2015-02-19  211.71   5137203  205.00  212.44  203.75
# 22 2015-02-20  217.11   5978376  210.78  217.60  209.81
# 23 2015-02-23  207.34   8487131  215.66  218.20  206.33
# 24 2015-02-24  204.11   6587298  207.29  207.29  201.70
# 25 2015-02-25  203.76   3907505  204.94  207.14  202.58
# 26 2015-02-26  207.19   6468020  204.00  211.09  202.22
# 27 2015-02-27  203.34   3871397  206.90  208.55  202.80
# 28 2015-03-02  197.33   7910402  202.70  203.34  195.83
# 29 2015-03-03  199.56   4430800  196.81  200.24  195.32

# %%
 # Shift close price up to predict next day
pd.concat([SortedData.Close, SortedData.Close.shift(-1)], axis=1)
# Out:
#        Close   Close
# 0     191.93  196.57
# 1     196.57  201.62
# 2     201.62  201.29
# 3     201.29  206.55
# 4     206.55  205.98
# ...      ...     ...
# 1254  524.86  537.92
# 1255  537.92  518.50
# 1256  518.50  513.49
# 1257  513.49  510.50
# 1258  510.50     NaN
#
# [1259 rows x 2 columns]

# %%
# Need to remove NA
# Regression - Try to predict Close price (y) from non Close price columns (X)
# Get training set (X_train)
def valid(col):
    return 'Close' not in col and 'Date' not in col
SortedData = SortedData.dropna() ### Pandas dropna() – Drop Null/NA Values from DataFrame 
### Remove the last close price (last row) because there is no tomorrow for the last row to predict!
X = SortedData[[x for x in SortedData.columns if valid(x)]].iloc[:-1] 
y = SortedData.Close.shift(-1).dropna()
### X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

### Split data into train and test subsets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.5, random_state = 0)

# %%
type(X_train)
# Out:
# pandas.core.frame.DataFrame

# %%
X_train.sort_index(ascending=True)
# Out:
#         Volume    Open    High     Low
# 0      4490681  193.87  194.12  187.04
# 3      3441052  200.29  203.50  198.33
# 4      3231121  201.83  208.62  201.05
# 7      3542577  201.07  205.98  196.50
# 11     3304417  218.29  221.48  216.80
# ...        ...     ...     ...     ...
# 1246  10292460  405.00  421.29  402.08
# 1247   9558386  424.50  430.70  421.71
# 1252  28463190  497.10  498.80  472.87
# 1253  12976830  481.79  484.94  473.70
# 1256  17368830  529.76  537.84  516.79
#
# [629 rows x 4 columns]

# %%
type(y_test)
# Out:
# pandas.core.series.Series

# %%
y_test.sort_index(ascending=True)
# Out:
# 1       201.62
# 2       201.29
# 5       199.37
# 6       205.20
# 8       210.94
#          ...
# 1250    492.14
# 1251    481.34
# 1254    537.92
# 1255    518.50
# 1257    510.50
# Name: Close, Length: 629, dtype: float64

# %%
# Create a model 
rf_model = RandomForestRegressor()

# %%
# Train the model, We learn the trend on the first half of the dataset
rf_model.fit(X_train, y_train)
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False)

# %%
# Get R2 measure (indicator of accuracy 1 is perfect 0 is horrible)
rf_model.score(X_test, y_test)
# Out:
# 0.9727187517286756

# %% [markdown]
# Close to 97%! base on this indicator, the predict must very close to the true data! <br>
# Let's plot predictions over actual values to see better:

# %%
### Now predict the value of the stock on the second half:
y_pred = rf_model.predict(X_test)

# %%
type(y_pred)
# Out:
# numpy.ndarray

# %%
y_pred[0:10]
# Out:
# array([310.3213, 249.3115, 191.625 , 210.5349, 256.3485, 210.9471,
#        333.6633, 284.0023, 224.6265, 287.1515])

# %%
import matplotlib.pyplot as plt
plt.plot(y_pred)

# %%
type(y_test)
# Out:
# pandas.core.series.Series

# %%
y_test2 = y_test.as_matrix()
type(y_test2)
# Out:
# numpy.ndarray

# %%
y_test2[0:10]
# Out:
# array([296.84, 253.12, 203.1 , 219.44, 235.14, 208.99, 325.6 , 269.49,
#        230.75, 276.24])

# %%
import matplotlib.pyplot as plt
plt.plot(y_test2)

# %% [markdown]
# Now let's plot predictions on top of test labels to see if we have a match. We'll plot one under the other and then reverse them to see if the mismatch is big or not:

# %%
import matplotlib.pyplot as plt
plt.plot(y_pred)
plt.plot(y_test2)

# %%
import matplotlib.pyplot as plt
plt.plot(y_test2)
plt.plot(y_pred)

# %% [markdown]
#  Let's tabulate:

# %%
type(y_test)
# Out:
# pandas.core.series.Series

# %%
pd.concat([pd.Series(y_pred), y_test.reset_index(drop=True)], axis=1)
# Out:
#             0   Close
# 0    310.3213  296.84
# 1    249.3115  253.12
# 2    191.6250  203.10
# 3    210.5349  219.44
# 4    256.3485  235.14
# ..        ...     ...
# 310  224.8407  232.74
# 311  314.8606  311.81
# 312  227.2496  238.17
# 313  342.9536  352.85
# 314  308.5743  302.56
#
# [315 rows x 2 columns]

# %%
sorted(zip(X.columns, rf_model.feature_importances_),
        key=lambda x: x[1], reverse=True)
# Out:
# [('High', 0.7235246204158919),
#  ('Low', 0.22198697036161322),
#  ('Open', 0.049209668429554425),
#  ('Volume', 0.005278740792940396)]

# %% [markdown]
# The close price of this stock has relatively higher relationship with today's highest price.

# %%
myPred = rf_model.predict([[17803470,530.25,548.58,528.41]])

# %%
myPred
# Out:
# array([515.7283])

# %% [markdown]
# <b>Conclusion :</b> In this model, I entered the stock data on January 21 to predict the close price of the day. The final result was 515.7283, and the actual result was 547.2. Quite similar. The R2 measure of thie model is 0.97.
