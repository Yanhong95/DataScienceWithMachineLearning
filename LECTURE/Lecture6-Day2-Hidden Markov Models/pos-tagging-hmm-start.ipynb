# %% [markdown]
# <div style="text-align: right">INFO 6105 Data Science Eng Methods and Tools, Lecture 6 Day 2</div>
# <div style="text-align: right">Dino Konstantopoulos, 12 February 2020, with material by Ankur Ankan and Abinash Panda</div>
#
# Some people have this to say about advantages of the **German** language:
#
# <br />
# <center>
# <img src="ipynb.images/german-flag.jpg" width=300 />
# </center>
#
# - It is better to keep the most important piece of information at the end, to keep people’s attention. In German, the main verb in conjugation is at the end of a sentence: *Sie (You) haben (have) bestimmt (definitely) noch (still) nicht (not) viele (many) anständige (respectable) Zauberer (wizard) **kennen gelernt** (met)*. In Spanish and English, we say all the important information first and, for this reason, we tend to interrupt each other in the middle of a sentence.
#
#
# - The purpose of words is to transmit **knowledge**, so they should be easily understood. Some people seem to use words no one knows just to look smart. In German, it is almost impossible to do this as names for objects describe those objects. I really love this about German: Glutenunverträglichkeit means gluten-not-compatible (celiac). It helped a lot while reading Harry Potter: Zauberer (wizard), Zauberwort (Magic word), Zaubererschule (School of Magic), Zauberstab (magic wand), Zaubererwelt (wizarding world), etc
#
# # POS tagging with Hidden Markov Models
#
# In this notebook you will witness how you can *cheat* Science by relying on data probabilities instead of trying to figure out the rules or laws of Science. I don't know the internals of [Universal Dependencies](https://universaldependencies.org/), but I suspect they do not worry about analyzing the structure of the German language, figuring out that the verb is at the end of a sentence, and accomodating for this in the German Tree Bank. Instead, their algorithms probably read in a lot of german text, and just by looking at the probabilities of where the verb lands in a sentence they can correctly figure out that it's at the end. Probabilities powers **statistics**, and having lots of data means your probabilities can be very *exact*.
#
# Not too many weeks ago, you called R libraries to do POS tagging for you. Now that you know everything about probabilities, *you* can do the same thing *on your own*!
#
# We'll use the [Brown]() corpus to build a [POS tagger](https://en.wikipedia.org/wiki/Part-of-speech_tagging), first using a simple [Bag of Words](https://en.wikipedia.org/wiki/Bag-of-words_model) model (***most probable POS by count***), then using a **Hidden Markov Model** (HMM) that gets *transition* and *emission* probabilities from [POS bigrams](https://en.wikipedia.org/wiki/Bigram) (given a POS, what's the most probable ***next*** POS in the sentence?).
#
# We'll divide the Brown corpus into training and test sets, and compare accuraces for BOW and HMM models.
#
# We'll use some advanced python structures that are often used in Natural Language Processing (NLP).
#
# # Reading in the Brown corpus efficiently

# %%
import matplotlib.pyplot as plt
import numpy as np
from IPython.core.display import HTML
from itertools import chain
from collections import Counter, defaultdict, namedtuple, OrderedDict
from pomegranate import State, HiddenMarkovModel, DiscreteDistribution
import os
from io import BytesIO
from itertools import chain
import random

# %% [markdown]
# Some advanced python-fu:
#
# Library `itertools` is a library of efficient iterators. `chain` makes an iterator that returns elements from the first iterable until it is exhausted, then proceeds to the next iterable, until all of the iterables are exhausted. It is used for treating consecutive sequences as a single sequence
#
# In python, a single star `*` unpacks the sequence/collection into positional arguments, so you can do this:
# ```(python)
# def sum(a, b):
#     return a + b
#
# values = (1, 2)
#
# s = sum(*values)
# ```
#
# This will unpack the tuple so that it actually executes as:
# ```(python)
# s = sum(1, 2)
# ```
#
# The double star `**` does the same, only using a dictionary and thus named arguments:
# ```(python)
# values = { 'a': 1, 'b': 2 }
# s = sum(**values)
# ```
#
# A python `frozenset` is just an immutable version of a Python set object.
#
# While elements of a set can be modified at any time, elements of frozen set remains the same after creation.
#
# So, frozen sets can be used as keys in a sictionary or as element of another set.
#
# `read_data` below reads files page by page (`\n\n`), then line by line (`\n`), uses the first line of a page as a key to an ordered dictionary, with the values being a zipper made out of words and POS tags. It accomodates the syntax of the [Brown corpus](https://en.wikipedia.org/wiki/Brown_Corpus), pictured here below.
#
# <br />
# <center>
# <img src="ipynb.images/brown.png" width=300 />
#     Header of Brown corpus
# </center>

# %%
def read_data(filename):
    """Read tagged sentence data"""
    with open(filename, 'r',encoding="UTF-8") as f:
        sentence_lines = [l.split("\n") for l in f.read().split("\n\n")]
    return OrderedDict(((s[0], Sentence(*zip(*[l.strip().split("\t")
                        for l in s[1:]]))) for s in sentence_lines if s[0]))

def read_tags(filename):
    """Read a list of word tag classes"""
    with open(filename, 'r') as f:
        tags = f.read().split("\n")
    return frozenset(tags)

Sentence = namedtuple("Sentence", "words tags")

# %% [markdown]
# Let's read in the Brown corpus to see if our python code works out:

# %%
tagset = read_tags("data/brown/aa.txt")
sentences = read_data("data/brown/bb.txt")
sentences
# Out:
# OrderedDict([('\ufeff1',
#               Sentence(words=('我们的', '班', '有', '一个', '很', '优秀的', '同学', '，', '她', '不光', '学习', '是', '我们', '班的', '第一名', '，', '而且', '在', '我们', '班', '还是', '经常', '受', '表扬的', '人物', '，', '她', '就是', '我们', '班的', '夏宇', '，', '她', '是', '一个', '特别', '优秀的', '学生', '，', '每年的', '三好', '学生', '，', '她', '还', '很', '热爱', '班', '集体'), tags=('our', 'class', 'have', 'a', 'very', 'good', 'classmate', ',', 'she', 'not only', 'study', 'is', 'our', 'class', 'first-class', ',', 'and', 'in', 'our', 'class', 'is', 'usually', 'been', 'Praise', 'character', ',', 'she', 'is', 'our', 'class', 'xiayu', ',', 'she', 'is', 'a', 'very', 'good', 'student', ',', 'annual', 'good', 'student', ',', 'she', 'also', 'very', 'like', 'class', 'collective'))),
#              ('2',
#               Sentence(words=('昨天', '放学的', '时候', '，', '同学们', '听到', '铃声', '，', '一窝蜂的', '都', '出去', '，', '她', '忽然', '停下', '脚步', '，', '我', '顺着', '她的', '目光', '，', '看见', '教室', '里', '非常', '杂乱', '，', '地上', '还有', '一大堆', '同学', '留下的', '纸屑'), tags=('yesterday', 'after school', 'time', ',', 'student', 'hear', 'ring bell', ',', 'a lot', 'all', 'get out', ',', 'she', 'suddently', 'stop', 'pace', ',', 'I', 'along', 'hers', 'eye', ',', 'see', 'class', 'in', 'very', 'massly', ',', 'ground', 'also', 'a load of', 'student', 'left', 'paper'))),
#              ('4',
#               Sentence(words=('我们', '扫地', '、', '摆', '小桌子', '、', '擦', '黑板', '，', '非常', '忙'), tags=('we', 'clean', ',', 'place', 'table', ',', 'wipe', 'blackboard', ',', 'very', 'busy'))),
#              ('5',
#               Sentence(words=('过了', '一会儿', '，', '终于', '打扫', '完了'), tags=('after', 'a while', ',', 'finally', 'clean', 'finish'))),
#              ('6',
#               Sentence(words=('夏宇', '把', '垃圾', '装在', '一个', '袋子', '，', '和', '我', '走出', '教室', '，', '关好', '门', '，', '去', '扔', '垃圾'), tags=('xiayu', 'place', 'garbage', 'in', 'a', 'bag', ',', 'with', 'me', 'go out', 'class', ',', 'close', 'door', ',', 'go', 'throw', 'garbage'))),
#              ('7',
#               Sentence(words=('她', '由于', '跑得', '太', '快', '，', '不小心', '摔倒了'), tags=('she', 'because', 'run', 'too', 'fast', ',', 'incaution', 'fell'))),
#              ('8',
#               Sentence(words=('我', '远远地', '看见', '她', '脸上', '带着', '痛苦的', '表情', '站了', '起来', '，', '揉了揉', '膝盖', '，', '坚持', '把', '垃圾', '扔掉', '，', '我们', '才', '收拾', '东西', '回', '家'), tags=('I', 'far away', 'see', 'she', 'face', 'with', 'painful', 'expression', 'stand', 'up', ',', 'knead', 'knee', ',', 'insist', 'hold', 'garbage', 'throw away', ',', 'we', 'just', 'clean', 'thing', 'back', 'home'))),
#              ('9',
#               Sentence(words=('这', '就是', '我们', '班的', '优秀', '同学', ',', '我', '也要', '向', '她', '学习', '，', '不仅', '要', '好好', '学习', '，', '更要', '爱护', '我们的', '班', '集体', '，', '因为', '班', '集体', '就是', '我们的', '家'), tags=('this', 'is', 'our', 'class', 'good', 'student', ',', 'I', 'also', 'from', 'her', 'study', ',', 'not only', 'want', 'well', 'study', ',', 'more', 'care', 'our', 'class', 'collective', ',', 'because', 'class', 'collective', 'is', 'our', 'home'))),
#              ('10',
#               Sentence(words=('三月', '到了', '，', '春', '姑娘', '也', '悄悄的', '来到了', '我们的', '身边', '，', '她', '轻手轻脚', '，', '悄悄的', '走着', '，', '浑身', '散发着', '清香', '，', '她', '羞涩地', '走着'), tags=('march', 'arrived', ',', 'spring', 'girl', 'also', 'quietly', 'arrive', 'our', 'side', ',', 'she', 'lightly', ',', 'silent', 'walking', ',', 'whole body', 'exude', 'fragrance', ',', 'she', 'shyly', 'walking'))),
#              ('11',
#               Sentence(words=('有一天', '，', '妈妈', '叫', '我', '去', '买', '东西', '，', '我', '开心的', '说', '好的', '妈妈', '我', '知道了'), tags=('one day', ',', 'mom', 'let', 'me', 'go', 'buy', 'something', ',', 'I', 'happily', 'said', 'Okay', 'mom', 'I', 'know'))),
#              ('12',
#               Sentence(words=('说完', '我', '就去', '买', '东西了'), tags=('after that', 'I', 'just', 'go', 'shopping'))),
#              ('13',
#               Sentence(words=('我', '说', '好的', '叔叔'), tags=('I', 'said', 'okay', 'uncle'))),
#              ('14',
#               Sentence(words=('我', '吃', '一', '苹果'), tags=('I', 'eat', 'one', 'apple'))),
#              ('15',
#               Sentence(words=('我', '爱', '吃', '梨'), tags=('I', 'love', 'eating', 'pears'))),
#              ('16',
#               Sentence(words=('我', '喜欢', '吃', '苹果', '和', '梨'), tags=('I', 'love', 'eating', 'apples', 'and', 'pears'))),
#              ('17',
#               Sentence(words=('我', '喜欢', '吃', '水果'), tags=('I', 'love', 'eating', 'apples'))),
#              ('18',
#               Sentence(words=('我', '喜欢', '吃', '苹果'), tags=('I', 'love', 'eating', 'apples'))),
#              ('19',
#               Sentence(words=('我', '喜欢', '吃', '水果'), tags=('I', 'love', 'eating', 'apple')))])

# %% [markdown]
# The class `Dataset` below incorporates our function above, reads in the Brown corpus and creates a collection of `keys`, a set of (unique) words, a sequence of words and a mirror sequence of tags as tuples, with `N` being the number of words in the Brown corpus.
#
# Then it splits all this nice data into a training and test decomposition by using the `Subset` class defined further below, which mirrors the `Dataset` class.

# %%
class Dataset(namedtuple("_Dataset", "sentences keys vocab X tagset Y training_set testing_set N stream")):
    def __new__(cls, tagfile, datafile, train_test_split=0.8, seed=112890):
        tagset = read_tags(tagfile)
        sentences = read_data(datafile)
        keys = tuple(sentences.keys())
        wordset = frozenset(chain(*[s.words for s in sentences.values()]))
        word_sequences = tuple([sentences[k].words for k in keys])
        tag_sequences = tuple([sentences[k].tags for k in keys])
        N = sum(1 for _ in chain(*(s.words for s in sentences.values())))
        
        # split data into train/test sets
        _keys = list(keys)
        if seed is not None: random.seed(seed)
        random.shuffle(_keys)
        split = int(train_test_split * len(_keys))
        training_data = Subset(sentences, _keys[:split])
        testing_data = Subset(sentences, _keys[split:])
        stream = tuple(zip(chain(*word_sequences), chain(*tag_sequences)))
        return super().__new__(cls, dict(sentences), keys, wordset, word_sequences, tagset,
                               tag_sequences, training_data, testing_data, N, stream.__iter__)

    def __len__(self):
        return len(self.sentences)

    def __iter__(self):
        return iter(self.sentences.items())
    
    
class Subset(namedtuple("BaseSet", "sentences keys vocab X tagset Y N stream")):
    def __new__(cls, sentences, keys):
        word_sequences = tuple([sentences[k].words for k in keys])
        tag_sequences = tuple([sentences[k].tags for k in keys])
        wordset = frozenset(chain(*word_sequences))
        tagset = frozenset(chain(*tag_sequences))
        N = sum(1 for _ in chain(*(sentences[k].words for k in keys)))
        stream = tuple(zip(chain(*word_sequences), chain(*tag_sequences)))
        return super().__new__(cls, {k: sentences[k] for k in keys}, keys, wordset, word_sequences,
                               tagset, tag_sequences, N, stream.__iter__)

    def __len__(self):
        return len(self.sentences)

    def __iter__(self):
        return iter(self.sentences.items())

# %% [markdown]
# Let's read in the Brown corpus *again*, leveraging our classes above now, which order the corpus into efficiently navigable structures:

# %%
data = Dataset("data/brown/tags-universal.txt", "data/brown/bb.txt", train_test_split=0.8)

print("There are {} sentences in the corpus.".format(len(data)))
print("There are {} sentences in the training set.".format(len(data.training_set)))
print("There are {} sentences in the testing set.".format(len(data.testing_set)))

assert len(data) == len(data.training_set) + len(data.testing_set), \
       "The number of sentences in the training set + testing set should sum to the number of sentences in the corpus"
# Out:
# There are 18 sentences in the corpus.
# There are 14 sentences in the training set.
# There are 4 sentences in the testing set.

# %%
print("There are a total of {} samples of {} unique words in the corpus."
      .format(data.N, len(data.vocab)))
print("There are {} samples of {} unique words in the training set."
      .format(data.training_set.N, len(data.training_set.vocab)))
print("There are {} samples of {} unique words in the testing set."
      .format(data.testing_set.N, len(data.testing_set.vocab)))
print("There are {} words in the test set that are missing in the training set."
      .format(len(data.testing_set.vocab - data.training_set.vocab)))

assert data.N == data.training_set.N + data.testing_set.N, \
       "The number of training + test samples should sum to the total number of samples"
# Out:
# There are a total of 256 samples of 145 unique words in the corpus.
# There are 180 samples of 115 unique words in the training set.
# There are 76 samples of 50 unique words in the testing set.
# There are 30 words in the test set that are missing in the training set.

# %% [markdown]
# Let's look at an example POS tagging:

# %% [markdown]
# This is how easy it is, now, to access words and associated tags, using the vocabulary of Machine Learning: `X` is the independent variable, and `Y` the dependent variable!

# %%
# accessing words with Dataset.X and tags with Dataset.Y 
for i in range(2):    
    print("Sentence {}:".format(i + 1), data.X[i])
    print()
    print("Labels {}:".format(i + 1), data.Y[i])
    print()
# Out:
# Sentence 1: ('我们的', '班', '有', '一个', '很', '优秀的', '同学', '，', '她', '不光', '学习', '是', '我们', '班的', '第一名', '，', '而且', '在', '我们', '班', '还是', '经常', '受', '表扬的', '人物', '，', '她', '就是', '我们', '班的', '夏宇', '，', '她', '是', '一个', '特别', '优秀的', '学生', '，', '每年的', '三好', '学生', '，', '她', '还', '很', '热爱', '班', '集体')
#
# Labels 1: ('our', 'class', 'have', 'a', 'very', 'good', 'classmate', ',', 'she', 'not only', 'study', 'is', 'our', 'class', 'first-class', ',', 'and', 'in', 'our', 'class', 'is', 'usually', 'been', 'Praise', 'character', ',', 'she', 'is', 'our', 'class', 'xiayu', ',', 'she', 'is', 'a', 'very', 'good', 'student', ',', 'annual', 'good', 'student', ',', 'she', 'also', 'very', 'like', 'class', 'collective')
#
# Sentence 2: ('昨天', '放学的', '时候', '，', '同学们', '听到', '铃声', '，', '一窝蜂的', '都', '出去', '，', '她', '忽然', '停下', '脚步', '，', '我', '顺着', '她的', '目光', '，', '看见', '教室', '里', '非常', '杂乱', '，', '地上', '还有', '一大堆', '同学', '留下的', '纸屑')
#
# Labels 2: ('yesterday', 'after school', 'time', ',', 'student', 'hear', 'ring bell', ',', 'a lot', 'all', 'get out', ',', 'she', 'suddently', 'stop', 'pace', ',', 'I', 'along', 'hers', 'eye', ',', 'see', 'class', 'in', 'very', 'massly', ',', 'ground', 'also', 'a load of', 'student', 'left', 'paper')

# %% [markdown]
# Use `Dataset.stream()` to enumerate (word, tag) samples for the entire corpus. Let's enumerate the first 4:

# %%
print("\nStream (word, tag) pairs:\n")
for i, pair in enumerate(data.stream()):
    print("\t", pair)
    if i > 3: break
# Out:
# Stream (word, tag) pairs:
#
# 	 ('我们的', 'our')
# 	 ('班', 'class')
# 	 ('有', 'have')
# 	 ('一个', 'a')
# 	 ('很', 'very')

# %% [markdown]
# These are all words and tags in our **training set**. Let's uncover the first 4:

# %%
words = [word for i, (word, tag) in enumerate(data.training_set.stream())]
tags = [tag for i, (word, tag) in enumerate(data.training_set.stream())]
words[0:4], tags[0:4]
# Out:
# (['过了', '一会儿', '，', '终于'], ['after', 'a while', ',', 'finally'])

# %% [markdown]
# # POS Tagger using BOW Model
#
# Let's create a dictionary of word + tag pairs where the values are just counts. Note that some words may be associated with different POS tags, in which case they will produce *distinct* pairs:

# %%
def pair_counts(tags, words):
    d = defaultdict(lambda: defaultdict(int))
    for tag, word in zip(tags, words):
        d[tag][word] += 1
    return d
        
word_counts = pair_counts(words, tags)

# %% [markdown]
# Let's produce a dictionary where words (keys) are associated with their ***most frequent*** POS tag:

# %%
mfc_table = dict((word, max(tags.keys(), key=lambda key: tags[key])) for word, tags in word_counts.items())

# %%
i = 0
for key, value in mfc_table.items():
    print(key, value)
    i += 1
    if i > 3: break
# Out:
# 过了 after
# 一会儿 a while
# ， ,
# 终于 finally

# %% [markdown]
# Python `namedtuple` supports a type of container-like dictionary that, like dictionaries, contains keys that are hashed to particular values. But it supports *both* access from key values as well as *iteration*, the functionality that dictionaries lack.
#
# Let's write a class that takes in a table in its constructor and adds `<MISSING>` POS tags if the word is missing from the training set (possible that a word is in the test set but missing from the training set). It also has a `viterbi` method that takes in the table and builds a sequence of states that we will use in our Hidden Markov Model.

# %%
FakeState = namedtuple('FakeState', 'name')

class MFCTagger:
    missing = FakeState(name = '<MISSING>')
    
    def __init__(self, table):
        self.table = defaultdict(lambda: MFCTagger.missing)
        self.table.update({word: FakeState(name=tag) for word, tag in table.items()})
        
    def viterbi(self, seq):
        """This method simplifies predictions by matching the Pomegranate viterbi() interface"""
        return 0., list(enumerate(["<start>"] + [self.table[w] for w in seq] + ["<end>"]))

# %%
mfc_model = MFCTagger(mfc_table)

# %% [markdown]
# So essentially we built a table that associates words with their most frequent POS tag. This is a simplistic **bag of words** (BOW) model. Let's see, given a sentence, if we *guess the hidden states* (POS tags) right!

# %%
def replace_unknown(sequence):
    return [w if w in data.training_set.vocab else 'nan' for w in sequence]

def simplify_decoding(X, model):    
    _, state_path = model.viterbi(replace_unknown(X)) 
    return [state[1].name for state in state_path[1:-1]]

# %%
for key in data.testing_set.keys[:3]:
    print("Sentence Key: {}\n".format(key))
    print("Sentence: {}\n".format(data.sentences[key].words))
    print("Predicted labels:\n-----------------")
    print(simplify_decoding(data.sentences[key].words, mfc_model))
    print()
    print("Actual labels:\n--------------")
    print(data.sentences[key].tags)
    print("\n")
# Out:
# Sentence Key: 12
#
# Sentence: ('说完', '我', '就去', '买', '东西了')
#
# Predicted labels:
# -----------------
# ['<MISSING>', 'I', '<MISSING>', 'buy', '<MISSING>']
#
# Actual labels:
# --------------
# ('after that', 'I', 'just', 'go', 'shopping')
#
#
# Sentence Key: 6
#
# Sentence: ('夏宇', '把', '垃圾', '装在', '一个', '袋子', '，', '和', '我', '走出', '教室', '，', '关好', '门', '，', '去', '扔', '垃圾')
#
# Predicted labels:
# -----------------
# ['<MISSING>', 'hold', 'garbage', '<MISSING>', '<MISSING>', '<MISSING>', ',', 'and', 'I', '<MISSING>', 'class', ',', '<MISSING>', '<MISSING>', ',', 'go', '<MISSING>', 'garbage']
#
# Actual labels:
# --------------
# ('xiayu', 'place', 'garbage', 'in', 'a', 'bag', ',', 'with', 'me', 'go out', 'class', ',', 'close', 'door', ',', 'go', 'throw', 'garbage')
#
#
# Sentence Key: ﻿1
#
# Sentence: ('我们的', '班', '有', '一个', '很', '优秀的', '同学', '，', '她', '不光', '学习', '是', '我们', '班的', '第一名', '，', '而且', '在', '我们', '班', '还是', '经常', '受', '表扬的', '人物', '，', '她', '就是', '我们', '班的', '夏宇', '，', '她', '是', '一个', '特别', '优秀的', '学生', '，', '每年的', '三好', '学生', '，', '她', '还', '很', '热爱', '班', '集体')
#
# Predicted labels:
# -----------------
# ['our', 'class', '<MISSING>', '<MISSING>', '<MISSING>', '<MISSING>', 'student', ',', 'she', '<MISSING>', 'study', '<MISSING>', 'we', 'class', '<MISSING>', ',', '<MISSING>', '<MISSING>', 'we', 'class', '<MISSING>', '<MISSING>', '<MISSING>', '<MISSING>', '<MISSING>', ',', 'she', 'is', 'we', 'class', '<MISSING>', ',', 'she', '<MISSING>', '<MISSING>', '<MISSING>', '<MISSING>', '<MISSING>', ',', '<MISSING>', '<MISSING>', '<MISSING>', ',', 'she', '<MISSING>', '<MISSING>', '<MISSING>', 'class', 'collective']
#
# Actual labels:
# --------------
# ('our', 'class', 'have', 'a', 'very', 'good', 'classmate', ',', 'she', 'not only', 'study', 'is', 'our', 'class', 'first-class', ',', 'and', 'in', 'our', 'class', 'is', 'usually', 'been', 'Praise', 'character', ',', 'she', 'is', 'our', 'class', 'xiayu', ',', 'she', 'is', 'a', 'very', 'good', 'student', ',', 'annual', 'good', 'student', ',', 'she', 'also', 'very', 'like', 'class', 'collective')

# %% [markdown]
# Pretty good! Let's evaluate the accuracy of our most-frequent-tag tagger:

# %%
def accuracy(X, Y, model):
    
    correct = total_predictions = 0
    for observations, actual_tags in zip(X, Y):
        
        # The model.viterbi call in simplify_decoding will return None if the HMM
        # raises an error (for example, if a test sentence contains a word that
        # is out of vocabulary for the training set). Any exception counts the
        # full sentence as an error (which makes this a conservative estimate).
        try:
            most_likely_tags = simplify_decoding(observations, model)
            correct += sum(p == t for p, t in zip(most_likely_tags, actual_tags))
        except:
            pass
        total_predictions += len(observations)
    return correct / total_predictions

# %%
mfc_training_acc = accuracy(data.training_set.X, data.training_set.Y, mfc_model)
print("training accuracy mfc_model: {:.2f}%".format(100 * mfc_training_acc))

mfc_testing_acc = accuracy(data.testing_set.X, data.testing_set.Y, mfc_model)
print("testing accuracy mfc_model: {:.2f}%".format(100 * mfc_testing_acc))
# Out:
# training accuracy mfc_model: 95.00%
# testing accuracy mfc_model: 40.79%

# %% [markdown]
# # Hidden Markov Model
#
# Let's build a POS tagger using a Hidden Markov Model.
#
# First, let's see how many POS tags we have in our corpus, using the python `Counter` structure that we used last week to count instances.

# %%
def unigram_counts(sequences):
    return Counter(sequences)

tags = [tag for i, (word, tag) in enumerate(data.training_set.stream())]
tag_unigrams = unigram_counts(tags)
tag_unigrams
# Out:
# Counter({'after': 1,
#          'a while': 1,
#          ',': 25,
#          'finally': 1,
#          'clean': 3,
#          'finish': 1,
#          'she': 5,
#          'because': 2,
#          'run': 1,
#          'too': 1,
#          'fast': 1,
#          'incaution': 1,
#          'fell': 1,
#          'this': 1,
#          'is': 2,
#          'our': 4,
#          'class': 4,
#          'good': 1,
#          'student': 3,
#          'I': 11,
#          'also': 3,
#          'from': 1,
#          'her': 1,
#          'study': 2,
#          'not only': 1,
#          'want': 1,
#          'well': 1,
#          'more': 1,
#          'care': 1,
#          'collective': 2,
#          'home': 2,
#          'said': 2,
#          'okay': 1,
#          'uncle': 1,
#          'love': 4,
#          'eating': 4,
#          'apples': 2,
#          'apple': 2,
#          'one day': 1,
#          'mom': 2,
#          'let': 1,
#          'me': 1,
#          'go': 1,
#          'buy': 1,
#          'something': 1,
#          'happily': 1,
#          'Okay': 1,
#          'know': 1,
#          'we': 2,
#          'place': 1,
#          'table': 1,
#          'wipe': 1,
#          'blackboard': 1,
#          'very': 2,
#          'busy': 1,
#          'and': 1,
#          'pears': 2,
#          'yesterday': 1,
#          'after school': 1,
#          'time': 1,
#          'hear': 1,
#          'ring bell': 1,
#          'a lot': 1,
#          'all': 1,
#          'get out': 1,
#          'suddently': 1,
#          'stop': 1,
#          'pace': 1,
#          'along': 1,
#          'hers': 1,
#          'eye': 1,
#          'see': 2,
#          'in': 1,
#          'massly': 1,
#          'ground': 1,
#          'a load of': 1,
#          'left': 1,
#          'paper': 1,
#          'march': 1,
#          'arrived': 1,
#          'spring': 1,
#          'girl': 1,
#          'quietly': 1,
#          'arrive': 1,
#          'side': 1,
#          'lightly': 1,
#          'silent': 1,
#          'walking': 2,
#          'whole body': 1,
#          'exude': 1,
#          'fragrance': 1,
#          'shyly': 1,
#          'eat': 1,
#          'one': 1,
#          'far away': 1,
#          'face': 1,
#          'with': 1,
#          'painful': 1,
#          'expression': 1,
#          'stand': 1,
#          'up': 1,
#          'knead': 1,
#          'knee': 1,
#          'insist': 1,
#          'hold': 1,
#          'garbage': 1,
#          'throw away': 1,
#          'just': 1,
#          'thing': 1,
#          'back': 1})

# %% [markdown]
# We'll *slightly* modify the code above to get our POS bigrams, from *both* training and test subsets, to uncover which POS tags follow which other POS tags. So, instead of a simple list of POS tags, `Counter` will count *neighboring* POS tuples!

# %%
def bigram_counts(sequences):
    return Counter(sequences)

tags = [tag for i, (word, tag) in enumerate(data.stream())]
o = [(tags[i],tags[i+1]) for i in range(0,len(tags)-2,2)]
tag_bigrams = bigram_counts(o)
tag_bigrams
# Out:
# Counter({('our', 'class'): 4,
#          ('have', 'a'): 1,
#          ('very', 'good'): 1,
#          ('classmate', ','): 1,
#          ('she', 'not only'): 1,
#          ('study', 'is'): 1,
#          ('first-class', ','): 1,
#          ('and', 'in'): 1,
#          ('is', 'usually'): 1,
#          ('been', 'Praise'): 1,
#          ('character', ','): 1,
#          ('she', 'is'): 2,
#          ('xiayu', ','): 1,
#          ('a', 'very'): 1,
#          ('good', 'student'): 2,
#          (',', 'annual'): 1,
#          (',', 'she'): 2,
#          ('also', 'very'): 1,
#          ('like', 'class'): 1,
#          ('collective', 'yesterday'): 1,
#          ('after school', 'time'): 1,
#          (',', 'student'): 1,
#          ('hear', 'ring bell'): 1,
#          (',', 'a lot'): 1,
#          ('all', 'get out'): 1,
#          ('suddently', 'stop'): 1,
#          ('pace', ','): 1,
#          ('I', 'along'): 1,
#          ('hers', 'eye'): 1,
#          (',', 'see'): 1,
#          ('class', 'in'): 1,
#          ('very', 'massly'): 1,
#          (',', 'ground'): 1,
#          ('also', 'a load of'): 1,
#          ('student', 'left'): 1,
#          ('paper', 'we'): 1,
#          ('clean', ','): 1,
#          ('place', 'table'): 1,
#          (',', 'wipe'): 1,
#          ('blackboard', ','): 1,
#          ('very', 'busy'): 1,
#          ('after', 'a while'): 1,
#          (',', 'finally'): 1,
#          ('clean', 'finish'): 1,
#          ('xiayu', 'place'): 1,
#          ('garbage', 'in'): 1,
#          ('a', 'bag'): 1,
#          (',', 'with'): 1,
#          ('me', 'go out'): 1,
#          ('class', ','): 1,
#          ('close', 'door'): 1,
#          (',', 'go'): 1,
#          ('throw', 'garbage'): 1,
#          ('she', 'because'): 1,
#          ('run', 'too'): 1,
#          ('fast', ','): 1,
#          ('incaution', 'fell'): 1,
#          ('I', 'far away'): 1,
#          ('see', 'she'): 1,
#          ('face', 'with'): 1,
#          ('painful', 'expression'): 1,
#          ('stand', 'up'): 1,
#          (',', 'knead'): 1,
#          ('knee', ','): 1,
#          ('insist', 'hold'): 1,
#          ('garbage', 'throw away'): 1,
#          (',', 'we'): 1,
#          ('just', 'clean'): 1,
#          ('thing', 'back'): 1,
#          ('home', 'this'): 1,
#          ('is', 'our'): 2,
#          ('class', 'good'): 1,
#          ('student', ','): 1,
#          ('I', 'also'): 1,
#          ('from', 'her'): 1,
#          ('study', ','): 1,
#          ('not only', 'want'): 1,
#          ('well', 'study'): 1,
#          (',', 'more'): 1,
#          ('care', 'our'): 1,
#          ('class', 'collective'): 2,
#          (',', 'because'): 1,
#          ('home', 'march'): 1,
#          ('arrived', ','): 1,
#          ('spring', 'girl'): 1,
#          ('also', 'quietly'): 1,
#          ('arrive', 'our'): 1,
#          ('side', ','): 1,
#          ('she', 'lightly'): 1,
#          (',', 'silent'): 1,
#          ('walking', ','): 1,
#          ('whole body', 'exude'): 1,
#          ('fragrance', ','): 1,
#          ('she', 'shyly'): 1,
#          ('walking', 'one day'): 1,
#          (',', 'mom'): 1,
#          ('let', 'me'): 1,
#          ('go', 'buy'): 1,
#          ('something', ','): 1,
#          ('I', 'happily'): 1,
#          ('said', 'Okay'): 1,
#          ('mom', 'I'): 1,
#          ('know', 'after that'): 1,
#          ('I', 'just'): 1,
#          ('go', 'shopping'): 1,
#          ('I', 'said'): 1,
#          ('okay', 'uncle'): 1,
#          ('I', 'eat'): 1,
#          ('one', 'apple'): 1,
#          ('I', 'love'): 5,
#          ('eating', 'pears'): 1,
#          ('eating', 'apples'): 3,
#          ('and', 'pears'): 1})

# %% [markdown]
# What tags do our sentences *begin* with?

# %%
def starting_counts(sequences):
    return Counter(sequences)

tags = [tag for i, (word, tag) in enumerate(data.stream())]
starts_tag = [i[0] for i in data.Y]
tag_starts = starting_counts(starts_tag)
tag_starts
# Out:
# Counter({'our': 1,
#          'yesterday': 1,
#          'we': 1,
#          'after': 1,
#          'xiayu': 1,
#          'she': 1,
#          'I': 8,
#          'this': 1,
#          'march': 1,
#          'one day': 1,
#          'after that': 1})

# %% [markdown]
# What tags do our sentences *end* with?

# %%
def ending_counts(sequences):    
    return Counter(sequences)

end_tag = [i[len(i)-1] for i in data.Y]
tag_ends = ending_counts(end_tag)
tag_ends
# Out:
# Counter({'collective': 1,
#          'paper': 1,
#          'busy': 1,
#          'finish': 1,
#          'garbage': 1,
#          'fell': 1,
#          'home': 2,
#          'walking': 1,
#          'know': 1,
#          'shopping': 1,
#          'uncle': 1,
#          'apple': 2,
#          'pears': 2,
#          'apples': 2})

# %% [markdown]
# Not surprising that most end with a period `.`! Ideally, we should end with the previous-to-last tag!

# %%
end_tag = [i[len(i)-2] for i in data.Y]
tag_ends = ending_counts(end_tag)
tag_ends
# Out:
# Counter({'class': 1,
#          'left': 1,
#          'very': 1,
#          'clean': 1,
#          'throw': 1,
#          'incaution': 1,
#          'back': 1,
#          'our': 1,
#          'shyly': 1,
#          'I': 1,
#          'go': 1,
#          'okay': 1,
#          'one': 1,
#          'eating': 4,
#          'and': 1})

# %% [markdown]
# Let's create our Hidden Markov Model and peek into most popular words per POS tag.
#
# `tag_words_count` contains words associated to each POS tag, arranged by frequency so that we can eventually evaluate *emission* probabilities, which are probabilities of observable states (wrods) given hidden states (POS tags).

# %%
hmm_model = HiddenMarkovModel(name="base-hmm-tagger")

tags = [tag for i, (word, tag) in enumerate(data.stream())]
words = [word for i, (word, tag) in enumerate(data.stream())]

tags_count = unigram_counts(tags)
tag_words_count = pair_counts(tags, words)

starting_tag_list = [i[0] for i in data.Y]
#ending_tag_list = [i[-1] if len(i)==1 else i[-2] for i in data.Y]
#ending_tag_list = [i[-1] for i in data.Y]
ending_tag_list = [i[len(i)-2] for i in data.Y]

starting_tag_count = starting_counts(starting_tag_list) #the number of times a tag occured at the start
ending_tag_count = ending_counts(ending_tag_list)       #the number of times a tag occured at the end

tag_words_count
# Out:
# defaultdict(<function __main__.pair_counts.<locals>.<lambda>()>,
#             {'our': defaultdict(int, {'我们的': 4, '我们': 4}),
#              'class': defaultdict(int, {'班': 5, '班的': 3, '教室': 2}),
#              'have': defaultdict(int, {'有': 1}),
#              'a': defaultdict(int, {'一个': 3}),
#              'very': defaultdict(int, {'很': 2, '特别': 1, '非常': 2}),
#              'good': defaultdict(int, {'优秀的': 2, '三好': 1, '优秀': 1}),
#              'classmate': defaultdict(int, {'同学': 1}),
#              ',': defaultdict(int, {'，': 31, '、': 2, ',': 1}),
#              'she': defaultdict(int, {'她': 9}),
#              'not only': defaultdict(int, {'不光': 1, '不仅': 1}),
#              'study': defaultdict(int, {'学习': 3}),
#              'is': defaultdict(int, {'是': 2, '还是': 1, '就是': 3}),
#              'first-class': defaultdict(int, {'第一名': 1}),
#              'and': defaultdict(int, {'而且': 1, '和': 1}),
#              'in': defaultdict(int, {'在': 1, '里': 1, '装在': 1}),
#              'usually': defaultdict(int, {'经常': 1}),
#              'been': defaultdict(int, {'受': 1}),
#              'Praise': defaultdict(int, {'表扬的': 1}),
#              'character': defaultdict(int, {'人物': 1}),
#              'xiayu': defaultdict(int, {'夏宇': 2}),
#              'student': defaultdict(int, {'学生': 2, '同学们': 1, '同学': 2}),
#              'annual': defaultdict(int, {'每年的': 1}),
#              'also': defaultdict(int, {'还': 1, '还有': 1, '也要': 1, '也': 1}),
#              'like': defaultdict(int, {'热爱': 1}),
#              'collective': defaultdict(int, {'集体': 3}),
#              'yesterday': defaultdict(int, {'昨天': 1}),
#              'after school': defaultdict(int, {'放学的': 1}),
#              'time': defaultdict(int, {'时候': 1}),
#              'hear': defaultdict(int, {'听到': 1}),
#              'ring bell': defaultdict(int, {'铃声': 1}),
#              'a lot': defaultdict(int, {'一窝蜂的': 1}),
#              'all': defaultdict(int, {'都': 1}),
#              'get out': defaultdict(int, {'出去': 1}),
#              'suddently': defaultdict(int, {'忽然': 1}),
#              'stop': defaultdict(int, {'停下': 1}),
#              'pace': defaultdict(int, {'脚步': 1}),
#              'I': defaultdict(int, {'我': 13}),
#              'along': defaultdict(int, {'顺着': 1}),
#              'hers': defaultdict(int, {'她的': 1}),
#              'eye': defaultdict(int, {'目光': 1}),
#              'see': defaultdict(int, {'看见': 2}),
#              'massly': defaultdict(int, {'杂乱': 1}),
#              'ground': defaultdict(int, {'地上': 1}),
#              'a load of': defaultdict(int, {'一大堆': 1}),
#              'left': defaultdict(int, {'留下的': 1}),
#              'paper': defaultdict(int, {'纸屑': 1}),
#              'we': defaultdict(int, {'我们': 2}),
#              'clean': defaultdict(int, {'扫地': 1, '打扫': 1, '收拾': 1}),
#              'place': defaultdict(int, {'摆': 1, '把': 1}),
#              'table': defaultdict(int, {'小桌子': 1}),
#              'wipe': defaultdict(int, {'擦': 1}),
#              'blackboard': defaultdict(int, {'黑板': 1}),
#              'busy': defaultdict(int, {'忙': 1}),
#              'after': defaultdict(int, {'过了': 1}),
#              'a while': defaultdict(int, {'一会儿': 1}),
#              'finally': defaultdict(int, {'终于': 1}),
#              'finish': defaultdict(int, {'完了': 1}),
#              'garbage': defaultdict(int, {'垃圾': 3}),
#              'bag': defaultdict(int, {'袋子': 1}),
#              'with': defaultdict(int, {'和': 1, '带着': 1}),
#              'me': defaultdict(int, {'我': 2}),
#              'go out': defaultdict(int, {'走出': 1}),
#              'close': defaultdict(int, {'关好': 1}),
#              'door': defaultdict(int, {'门': 1}),
#              'go': defaultdict(int, {'去': 2, '买': 1}),
#              'throw': defaultdict(int, {'扔': 1}),
#              'because': defaultdict(int, {'由于': 1, '因为': 1}),
#              'run': defaultdict(int, {'跑得': 1}),
#              'too': defaultdict(int, {'太': 1}),
#              'fast': defaultdict(int, {'快': 1}),
#              'incaution': defaultdict(int, {'不小心': 1}),
#              'fell': defaultdict(int, {'摔倒了': 1}),
#              'far away': defaultdict(int, {'远远地': 1}),
#              'face': defaultdict(int, {'脸上': 1}),
#              'painful': defaultdict(int, {'痛苦的': 1}),
#              'expression': defaultdict(int, {'表情': 1}),
#              'stand': defaultdict(int, {'站了': 1}),
#              'up': defaultdict(int, {'起来': 1}),
#              'knead': defaultdict(int, {'揉了揉': 1}),
#              'knee': defaultdict(int, {'膝盖': 1}),
#              'insist': defaultdict(int, {'坚持': 1}),
#              'hold': defaultdict(int, {'把': 1}),
#              'throw away': defaultdict(int, {'扔掉': 1}),
#              'just': defaultdict(int, {'才': 1, '就去': 1}),
#              'thing': defaultdict(int, {'东西': 1}),
#              'back': defaultdict(int, {'回': 1}),
#              'home': defaultdict(int, {'家': 2}),
#              'this': defaultdict(int, {'这': 1}),
#              'from': defaultdict(int, {'向': 1}),
#              'her': defaultdict(int, {'她': 1}),
#              'want': defaultdict(int, {'要': 1}),
#              'well': defaultdict(int, {'好好': 1}),
#              'more': defaultdict(int, {'更要': 1}),
#              'care': defaultdict(int, {'爱护': 1}),
#              'march': defaultdict(int, {'三月': 1}),
#              'arrived': defaultdict(int, {'到了': 1}),
#              'spring': defaultdict(int, {'春': 1}),
#              'girl': defaultdict(int, {'姑娘': 1}),
#              'quietly': defaultdict(int, {'悄悄的': 1}),
#              'arrive': defaultdict(int, {'来到了': 1}),
#              'side': defaultdict(int, {'身边': 1}),
#              'lightly': defaultdict(int, {'轻手轻脚': 1}),
#              'silent': defaultdict(int, {'悄悄的': 1}),
#              'walking': defaultdict(int, {'走着': 2}),
#              'whole body': defaultdict(int, {'浑身': 1}),
#              'exude': defaultdict(int, {'散发着': 1}),
#              'fragrance': defaultdict(int, {'清香': 1}),
#              'shyly': defaultdict(int, {'羞涩地': 1}),
#              'one day': defaultdict(int, {'有一天': 1}),
#              'mom': defaultdict(int, {'妈妈': 2}),
#              'let': defaultdict(int, {'叫': 1}),
#              'buy': defaultdict(int, {'买': 1}),
#              'something': defaultdict(int, {'东西': 1}),
#              'happily': defaultdict(int, {'开心的': 1}),
#              'said': defaultdict(int, {'说': 2}),
#              'Okay': defaultdict(int, {'好的': 1}),
#              'know': defaultdict(int, {'知道了': 1}),
#              'after that': defaultdict(int, {'说完': 1}),
#              'shopping': defaultdict(int, {'东西了': 1}),
#              'okay': defaultdict(int, {'好的': 1}),
#              'uncle': defaultdict(int, {'叔叔': 1}),
#              'eat': defaultdict(int, {'吃': 1}),
#              'one': defaultdict(int, {'一': 1}),
#              'apple': defaultdict(int, {'苹果': 1, '水果': 1}),
#              'love': defaultdict(int, {'爱': 1, '喜欢': 4}),
#              'eating': defaultdict(int, {'吃': 5}),
#              'pears': defaultdict(int, {'梨': 2}),
#              'apples': defaultdict(int, {'苹果': 2, '水果': 1})})

# %%
ending_tag_list
# Out:
# ['class',
#  'left',
#  'very',
#  'clean',
#  'throw',
#  'incaution',
#  'back',
#  'our',
#  'shyly',
#  'I',
#  'go',
#  'okay',
#  'one',
#  'eating',
#  'and',
#  'eating',
#  'eating',
#  'eating']

# %% [markdown]
# Let's convert word frequencies by POS tag to probabilities by dividing by the total number of words per POS tag, yielding the `distribution` of words.
#
# We'll define HMM emission probabilities using that `distribution`.

# %%
tag_words_count
# Out:
# defaultdict(<function __main__.pair_counts.<locals>.<lambda>()>,
#             {'our': defaultdict(int, {'我们的': 4, '我们': 4}),
#              'class': defaultdict(int, {'班': 5, '班的': 3, '教室': 2}),
#              'have': defaultdict(int, {'有': 1}),
#              'a': defaultdict(int, {'一个': 3}),
#              'very': defaultdict(int, {'很': 2, '特别': 1, '非常': 2}),
#              'good': defaultdict(int, {'优秀的': 2, '三好': 1, '优秀': 1}),
#              'classmate': defaultdict(int, {'同学': 1}),
#              ',': defaultdict(int, {'，': 31, '、': 2, ',': 1}),
#              'she': defaultdict(int, {'她': 9}),
#              'not only': defaultdict(int, {'不光': 1, '不仅': 1}),
#              'study': defaultdict(int, {'学习': 3}),
#              'is': defaultdict(int, {'是': 2, '还是': 1, '就是': 3}),
#              'first-class': defaultdict(int, {'第一名': 1}),
#              'and': defaultdict(int, {'而且': 1, '和': 1}),
#              'in': defaultdict(int, {'在': 1, '里': 1, '装在': 1}),
#              'usually': defaultdict(int, {'经常': 1}),
#              'been': defaultdict(int, {'受': 1}),
#              'Praise': defaultdict(int, {'表扬的': 1}),
#              'character': defaultdict(int, {'人物': 1}),
#              'xiayu': defaultdict(int, {'夏宇': 2}),
#              'student': defaultdict(int, {'学生': 2, '同学们': 1, '同学': 2}),
#              'annual': defaultdict(int, {'每年的': 1}),
#              'also': defaultdict(int, {'还': 1, '还有': 1, '也要': 1, '也': 1}),
#              'like': defaultdict(int, {'热爱': 1}),
#              'collective': defaultdict(int, {'集体': 3}),
#              'yesterday': defaultdict(int, {'昨天': 1}),
#              'after school': defaultdict(int, {'放学的': 1}),
#              'time': defaultdict(int, {'时候': 1}),
#              'hear': defaultdict(int, {'听到': 1}),
#              'ring bell': defaultdict(int, {'铃声': 1}),
#              'a lot': defaultdict(int, {'一窝蜂的': 1}),
#              'all': defaultdict(int, {'都': 1}),
#              'get out': defaultdict(int, {'出去': 1}),
#              'suddently': defaultdict(int, {'忽然': 1}),
#              'stop': defaultdict(int, {'停下': 1}),
#              'pace': defaultdict(int, {'脚步': 1}),
#              'I': defaultdict(int, {'我': 13}),
#              'along': defaultdict(int, {'顺着': 1}),
#              'hers': defaultdict(int, {'她的': 1}),
#              'eye': defaultdict(int, {'目光': 1}),
#              'see': defaultdict(int, {'看见': 2}),
#              'massly': defaultdict(int, {'杂乱': 1}),
#              'ground': defaultdict(int, {'地上': 1}),
#              'a load of': defaultdict(int, {'一大堆': 1}),
#              'left': defaultdict(int, {'留下的': 1}),
#              'paper': defaultdict(int, {'纸屑': 1}),
#              'we': defaultdict(int, {'我们': 2}),
#              'clean': defaultdict(int, {'扫地': 1, '打扫': 1, '收拾': 1}),
#              'place': defaultdict(int, {'摆': 1, '把': 1}),
#              'table': defaultdict(int, {'小桌子': 1}),
#              'wipe': defaultdict(int, {'擦': 1}),
#              'blackboard': defaultdict(int, {'黑板': 1}),
#              'busy': defaultdict(int, {'忙': 1}),
#              'after': defaultdict(int, {'过了': 1}),
#              'a while': defaultdict(int, {'一会儿': 1}),
#              'finally': defaultdict(int, {'终于': 1}),
#              'finish': defaultdict(int, {'完了': 1}),
#              'garbage': defaultdict(int, {'垃圾': 3}),
#              'bag': defaultdict(int, {'袋子': 1}),
#              'with': defaultdict(int, {'和': 1, '带着': 1}),
#              'me': defaultdict(int, {'我': 2}),
#              'go out': defaultdict(int, {'走出': 1}),
#              'close': defaultdict(int, {'关好': 1}),
#              'door': defaultdict(int, {'门': 1}),
#              'go': defaultdict(int, {'去': 2, '买': 1}),
#              'throw': defaultdict(int, {'扔': 1}),
#              'because': defaultdict(int, {'由于': 1, '因为': 1}),
#              'run': defaultdict(int, {'跑得': 1}),
#              'too': defaultdict(int, {'太': 1}),
#              'fast': defaultdict(int, {'快': 1}),
#              'incaution': defaultdict(int, {'不小心': 1}),
#              'fell': defaultdict(int, {'摔倒了': 1}),
#              'far away': defaultdict(int, {'远远地': 1}),
#              'face': defaultdict(int, {'脸上': 1}),
#              'painful': defaultdict(int, {'痛苦的': 1}),
#              'expression': defaultdict(int, {'表情': 1}),
#              'stand': defaultdict(int, {'站了': 1}),
#              'up': defaultdict(int, {'起来': 1}),
#              'knead': defaultdict(int, {'揉了揉': 1}),
#              'knee': defaultdict(int, {'膝盖': 1}),
#              'insist': defaultdict(int, {'坚持': 1}),
#              'hold': defaultdict(int, {'把': 1}),
#              'throw away': defaultdict(int, {'扔掉': 1}),
#              'just': defaultdict(int, {'才': 1, '就去': 1}),
#              'thing': defaultdict(int, {'东西': 1}),
#              'back': defaultdict(int, {'回': 1}),
#              'home': defaultdict(int, {'家': 2}),
#              'this': defaultdict(int, {'这': 1}),
#              'from': defaultdict(int, {'向': 1}),
#              'her': defaultdict(int, {'她': 1}),
#              'want': defaultdict(int, {'要': 1}),
#              'well': defaultdict(int, {'好好': 1}),
#              'more': defaultdict(int, {'更要': 1}),
#              'care': defaultdict(int, {'爱护': 1}),
#              'march': defaultdict(int, {'三月': 1}),
#              'arrived': defaultdict(int, {'到了': 1}),
#              'spring': defaultdict(int, {'春': 1}),
#              'girl': defaultdict(int, {'姑娘': 1}),
#              'quietly': defaultdict(int, {'悄悄的': 1}),
#              'arrive': defaultdict(int, {'来到了': 1}),
#              'side': defaultdict(int, {'身边': 1}),
#              'lightly': defaultdict(int, {'轻手轻脚': 1}),
#              'silent': defaultdict(int, {'悄悄的': 1}),
#              'walking': defaultdict(int, {'走着': 2}),
#              'whole body': defaultdict(int, {'浑身': 1}),
#              'exude': defaultdict(int, {'散发着': 1}),
#              'fragrance': defaultdict(int, {'清香': 1}),
#              'shyly': defaultdict(int, {'羞涩地': 1}),
#              'one day': defaultdict(int, {'有一天': 1}),
#              'mom': defaultdict(int, {'妈妈': 2}),
#              'let': defaultdict(int, {'叫': 1}),
#              'buy': defaultdict(int, {'买': 1}),
#              'something': defaultdict(int, {'东西': 1}),
#              'happily': defaultdict(int, {'开心的': 1}),
#              'said': defaultdict(int, {'说': 2}),
#              'Okay': defaultdict(int, {'好的': 1}),
#              'know': defaultdict(int, {'知道了': 1}),
#              'after that': defaultdict(int, {'说完': 1}),
#              'shopping': defaultdict(int, {'东西了': 1}),
#              'okay': defaultdict(int, {'好的': 1}),
#              'uncle': defaultdict(int, {'叔叔': 1}),
#              'eat': defaultdict(int, {'吃': 1}),
#              'one': defaultdict(int, {'一': 1}),
#              'apple': defaultdict(int, {'苹果': 1, '水果': 1}),
#              'love': defaultdict(int, {'爱': 1, '喜欢': 4}),
#              'eating': defaultdict(int, {'吃': 5}),
#              'pears': defaultdict(int, {'梨': 2}),
#              'apples': defaultdict(int, {'苹果': 2, '水果': 1})})

# %%
to_pass_states = []
for tag, words_dict in tag_words_count.items():
    total = float(sum(words_dict.values()))
    
    distribution = {word: count/total for word, count in words_dict.items()}
    print(distribution)
    tag_emissions = DiscreteDistribution(distribution)
    tag_state = State(tag_emissions, name=tag)
    to_pass_states.append(tag_state)
# Out:
# {'我们的': 0.5, '我们': 0.5}
# {'班': 0.5, '班的': 0.3, '教室': 0.2}
# {'有': 1.0}
# {'一个': 1.0}
# {'很': 0.4, '特别': 0.2, '非常': 0.4}
# {'优秀的': 0.5, '三好': 0.25, '优秀': 0.25}
# {'同学': 1.0}
# {'，': 0.9117647058823529, '、': 0.058823529411764705, ',': 0.029411764705882353}
# {'她': 1.0}
# {'不光': 0.5, '不仅': 0.5}
# {'学习': 1.0}
# {'是': 0.3333333333333333, '还是': 0.16666666666666666, '就是': 0.5}
# {'第一名': 1.0}
# {'而且': 0.5, '和': 0.5}
# {'在': 0.3333333333333333, '里': 0.3333333333333333, '装在': 0.3333333333333333}
# {'经常': 1.0}
# {'受': 1.0}
# {'表扬的': 1.0}
# {'人物': 1.0}
# {'夏宇': 1.0}
# {'学生': 0.4, '同学们': 0.2, '同学': 0.4}
# {'每年的': 1.0}
# {'还': 0.25, '还有': 0.25, '也要': 0.25, '也': 0.25}
# {'热爱': 1.0}
# {'集体': 1.0}
# {'昨天': 1.0}
# {'放学的': 1.0}
# {'时候': 1.0}
# {'听到': 1.0}
# {'铃声': 1.0}
# {'一窝蜂的': 1.0}
# {'都': 1.0}
# {'出去': 1.0}
# {'忽然': 1.0}
# {'停下': 1.0}
# {'脚步': 1.0}
# {'我': 1.0}
# {'顺着': 1.0}
# {'她的': 1.0}
# {'目光': 1.0}
# {'看见': 1.0}
# {'杂乱': 1.0}
# {'地上': 1.0}
# {'一大堆': 1.0}
# {'留下的': 1.0}
# {'纸屑': 1.0}
# {'我们': 1.0}
# {'扫地': 0.3333333333333333, '打扫': 0.3333333333333333, '收拾': 0.3333333333333333}
# {'摆': 0.5, '把': 0.5}
# {'小桌子': 1.0}
# {'擦': 1.0}
# {'黑板': 1.0}
# {'忙': 1.0}
# {'过了': 1.0}
# {'一会儿': 1.0}
# {'终于': 1.0}
# {'完了': 1.0}
# {'垃圾': 1.0}
# {'袋子': 1.0}
# {'和': 0.5, '带着': 0.5}
# {'我': 1.0}
# {'走出': 1.0}
# {'关好': 1.0}
# {'门': 1.0}
# {'去': 0.6666666666666666, '买': 0.3333333333333333}
# {'扔': 1.0}
# {'由于': 0.5, '因为': 0.5}
# {'跑得': 1.0}
# {'太': 1.0}
# {'快': 1.0}
# {'不小心': 1.0}
# {'摔倒了': 1.0}
# {'远远地': 1.0}
# {'脸上': 1.0}
# {'痛苦的': 1.0}
# {'表情': 1.0}
# {'站了': 1.0}
# {'起来': 1.0}
# {'揉了揉': 1.0}
# {'膝盖': 1.0}
# {'坚持': 1.0}
# {'把': 1.0}
# {'扔掉': 1.0}
# {'才': 0.5, '就去': 0.5}
# {'东西': 1.0}
# {'回': 1.0}
# {'家': 1.0}
# {'这': 1.0}
# {'向': 1.0}
# {'她': 1.0}
# {'要': 1.0}
# {'好好': 1.0}
# {'更要': 1.0}
# {'爱护': 1.0}
# {'三月': 1.0}
# {'到了': 1.0}
# {'春': 1.0}
# {'姑娘': 1.0}
# {'悄悄的': 1.0}
# {'来到了': 1.0}
# {'身边': 1.0}
# {'轻手轻脚': 1.0}
# {'悄悄的': 1.0}
# {'走着': 1.0}
# {'浑身': 1.0}
# {'散发着': 1.0}
# {'清香': 1.0}
# {'羞涩地': 1.0}
# {'有一天': 1.0}
# {'妈妈': 1.0}
# {'叫': 1.0}
# {'买': 1.0}
# {'东西': 1.0}
# {'开心的': 1.0}
# {'说': 1.0}
# {'好的': 1.0}
# {'知道了': 1.0}
# {'说完': 1.0}
# {'东西了': 1.0}
# {'好的': 1.0}
# {'叔叔': 1.0}
# {'吃': 1.0}
# {'一': 1.0}
# {'苹果': 0.5, '水果': 0.5}
# {'爱': 0.2, '喜欢': 0.8}
# {'吃': 1.0}
# {'梨': 1.0}
# {'苹果': 0.6666666666666666, '水果': 0.3333333333333333}

# %%
distribution
# Out:
# {'苹果': 0.6666666666666666, '水果': 0.3333333333333333}

# %% [markdown]
# `to_pass_states` yields the probability distribution of words per POS tag:

# %%
to_pass_states
# Out:
# [{
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u6211\u4eec\u7684" : 0.5,
#                  "\u6211\u4eec" : 0.5
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "our",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u73ed" : 0.5,
#                  "\u73ed\u7684" : 0.3,
#                  "\u6559\u5ba4" : 0.2
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "class",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u6709" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "have",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u4e00\u4e2a" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "a",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u5f88" : 0.4,
#                  "\u7279\u522b" : 0.2,
#                  "\u975e\u5e38" : 0.4
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "very",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u4f18\u79c0\u7684" : 0.5,
#                  "\u4e09\u597d" : 0.25,
#                  "\u4f18\u79c0" : 0.25
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "good",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u540c\u5b66" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "classmate",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\uff0c" : 0.9117647058823529,
#                  "\u3001" : 0.058823529411764705,
#                  "," : 0.029411764705882353
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : ",",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u5979" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "she",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u4e0d\u5149" : 0.5,
#                  "\u4e0d\u4ec5" : 0.5
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "not only",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u5b66\u4e60" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "study",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u662f" : 0.3333333333333333,
#                  "\u8fd8\u662f" : 0.16666666666666666,
#                  "\u5c31\u662f" : 0.5
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "is",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u7b2c\u4e00\u540d" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "first-class",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u800c\u4e14" : 0.5,
#                  "\u548c" : 0.5
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "and",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u5728" : 0.3333333333333333,
#                  "\u91cc" : 0.3333333333333333,
#                  "\u88c5\u5728" : 0.3333333333333333
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "in",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u7ecf\u5e38" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "usually",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u53d7" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "been",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u8868\u626c\u7684" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Praise",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u4eba\u7269" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "character",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u590f\u5b87" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "xiayu",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u5b66\u751f" : 0.4,
#                  "\u540c\u5b66\u4eec" : 0.2,
#                  "\u540c\u5b66" : 0.4
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "student",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u6bcf\u5e74\u7684" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "annual",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u8fd8" : 0.25,
#                  "\u8fd8\u6709" : 0.25,
#                  "\u4e5f\u8981" : 0.25,
#                  "\u4e5f" : 0.25
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "also",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u70ed\u7231" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "like",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u96c6\u4f53" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "collective",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u6628\u5929" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "yesterday",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u653e\u5b66\u7684" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "after school",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u65f6\u5019" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "time",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u542c\u5230" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "hear",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u94c3\u58f0" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "ring bell",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u4e00\u7a9d\u8702\u7684" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "a lot",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u90fd" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "all",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u51fa\u53bb" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "get out",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u5ffd\u7136" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "suddently",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u505c\u4e0b" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "stop",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u811a\u6b65" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "pace",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u6211" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "I",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u987a\u7740" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "along",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u5979\u7684" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "hers",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u76ee\u5149" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "eye",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u770b\u89c1" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "see",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u6742\u4e71" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "massly",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u5730\u4e0a" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "ground",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u4e00\u5927\u5806" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "a load of",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u7559\u4e0b\u7684" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "left",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u7eb8\u5c51" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "paper",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u6211\u4eec" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "we",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u626b\u5730" : 0.3333333333333333,
#                  "\u6253\u626b" : 0.3333333333333333,
#                  "\u6536\u62fe" : 0.3333333333333333
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "clean",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u6446" : 0.5,
#                  "\u628a" : 0.5
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "place",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u5c0f\u684c\u5b50" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "table",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u64e6" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "wipe",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u9ed1\u677f" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "blackboard",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u5fd9" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "busy",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u8fc7\u4e86" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "after",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u4e00\u4f1a\u513f" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "a while",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u7ec8\u4e8e" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "finally",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u5b8c\u4e86" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "finish",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u5783\u573e" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "garbage",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u888b\u5b50" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "bag",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u548c" : 0.5,
#                  "\u5e26\u7740" : 0.5
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "with",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u6211" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "me",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u8d70\u51fa" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "go out",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u5173\u597d" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "close",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u95e8" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "door",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u53bb" : 0.6666666666666666,
#                  "\u4e70" : 0.3333333333333333
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "go",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u6254" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "throw",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u7531\u4e8e" : 0.5,
#                  "\u56e0\u4e3a" : 0.5
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "because",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u8dd1\u5f97" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "run",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u592a" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "too",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u5feb" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "fast",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u4e0d\u5c0f\u5fc3" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "incaution",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u6454\u5012\u4e86" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "fell",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u8fdc\u8fdc\u5730" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "far away",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u8138\u4e0a" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "face",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u75db\u82e6\u7684" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "painful",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u8868\u60c5" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "expression",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u7ad9\u4e86" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "stand",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u8d77\u6765" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "up",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u63c9\u4e86\u63c9" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "knead",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u819d\u76d6" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "knee",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u575a\u6301" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "insist",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u628a" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "hold",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u6254\u6389" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "throw away",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u624d" : 0.5,
#                  "\u5c31\u53bb" : 0.5
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "just",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u4e1c\u897f" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "thing",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u56de" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "back",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u5bb6" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "home",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u8fd9" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "this",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u5411" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "from",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u5979" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "her",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u8981" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "want",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u597d\u597d" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "well",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u66f4\u8981" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "more",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u7231\u62a4" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "care",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u4e09\u6708" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "march",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u5230\u4e86" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "arrived",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u6625" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "spring",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u59d1\u5a18" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "girl",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u6084\u6084\u7684" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "quietly",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u6765\u5230\u4e86" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "arrive",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u8eab\u8fb9" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "side",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u8f7b\u624b\u8f7b\u811a" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "lightly",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u6084\u6084\u7684" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "silent",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u8d70\u7740" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "walking",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u6d51\u8eab" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "whole body",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u6563\u53d1\u7740" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "exude",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u6e05\u9999" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "fragrance",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u7f9e\u6da9\u5730" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "shyly",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u6709\u4e00\u5929" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "one day",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u5988\u5988" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "mom",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u53eb" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "let",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u4e70" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "buy",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u4e1c\u897f" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "something",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u5f00\u5fc3\u7684" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "happily",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u8bf4" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "said",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u597d\u7684" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Okay",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u77e5\u9053\u4e86" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "know",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u8bf4\u5b8c" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "after that",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u4e1c\u897f\u4e86" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "shopping",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u597d\u7684" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "okay",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u53d4\u53d4" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "uncle",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u5403" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "eat",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u4e00" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "one",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u82f9\u679c" : 0.5,
#                  "\u6c34\u679c" : 0.5
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "apple",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u7231" : 0.2,
#                  "\u559c\u6b22" : 0.8
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "love",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u5403" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "eating",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u68a8" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "pears",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u82f9\u679c" : 0.6666666666666666,
#                  "\u6c34\u679c" : 0.3333333333333333
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "apples",
#      "weight" : 1.0
#  }]

# %% [markdown]
# Let's add states to our model:

# %%
hmm_model.add_states()

# %% [markdown]
# The start probability for each tag is how many times it is a sentence-starting POS tag divided by its total count. We build the starting transitions for our HMM model:

# %%
start_prob={}

for tag in tags:
    start_prob[tag] = starting_tag_count[tag] / tags_count[tag]

for tag_state in to_pass_states :
    hmm_model.add_transition(hmm_model.start, tag_state, start_prob[tag_state.name])

# %% [markdown]
# The end probability for each tag is how many times it is a sentence-ending POS tag divided by its total count. We build the ending transitions for our HMM model:

# %%
end_prob={}

for tag in tags:
    end_prob[tag] = ending_tag_count[tag]/tags_count[tag]
    
for tag_state in to_pass_states :
    hmm_model.add_transition(tag_state, hmm_model.end, end_prob[tag_state.name])
    print(tag_state)
# Out:
# {
#     "class" : "State",
#     "distribution" : {
#         "class" : "Distribution",
#         "dtype" : "str",
#         "name" : "DiscreteDistribution",
#         "parameters" : [
#             {
#                 "\u6211\u4eec\u7684" : 0.5,
#                 "\u6211\u4eec" : 0.5
#             }
#         ],
#         "frozen" : false
#     },
#     "name" : "our",
#     "weight" : 1.0
# }
# {
#     "class" : "State",
#     "distribution" : {
#         "class" : "Distribution",
#         "dtype" : "str",
#         "name" : "DiscreteDistribution",
#         "parameters" : [
#             {
#                 "\u73ed" : 0.5,
#                 "\u73ed\u7684" : 0.3,
#                 "\u6559\u5ba4" : 0.2
#             }
#         ],
#         "frozen" : false
#     },
#     "name" : "class",
#     "weight" : 1.0
# }
# {
#     "class" : "State",
#     "distribution" : {
#         "class" : "Distribution",
#         "dtype" : "str",
#         "name" : "DiscreteDistribution",
#         "parameters" : [
#             {
#                 "\u6709" : 1.0
#             }
#         ],
#         "frozen" : false
#     },
#     "name" : "have",
#     "weight" : 1.0
# }
# {
#     "class" : "State",
#     "distribution" : {
#         "class" : "Distribution",
#         "dtype" : "str",
#         "name" : "DiscreteDistribution",
#         "parameters" : [
#             {
#                 "\u4e00\u4e2a" : 1.0
#             }
#         ],
#         "frozen" : false
#     },
#     "name" : "a",
#     "weight" : 1.0
# }
# {
#     "class" : "State",
#     "distribution" : {
#         "class" : "Distribution",
#         "dtype" : "str",
#         "name" : "DiscreteDistribution",
#         "parameters" : [
#             {
#                 "\u5f88" : 0.4,
#                 "\u7279\u522b" : 0.2,
#                 "\u975e\u5e38" : 0.4
#             }
#         ],
#         "frozen" : false
#     },
#     "name" : "very",
#     "weight" : 1.0
# }
# {
#     "class" : "State",
#     "distribution" : {
#         "class" : "Distribution",
#         "dtype" : "str",
#         "name" : "DiscreteDistribution",
#         "parameters" : [
#             {
#                 "\u4f18\u79c0\u7684" : 0.5,
#                 "\u4e09\u597d" : 0.25,
#                 "\u4f18\u79c0" : 0.25
#             }
#         ],
#         "frozen" : false
#     },
#     "name" : "good",
#     "weight" : 1.0
# }
# {
#     "class" : "State",
#     "distribution" : {
#         "class" : "Distribution",
#         "dtype" : "str",
#         "name" : "DiscreteDistribution",
#         "parameters" : [
#             {
#                 "\u540c\u5b66" : 1.0
#             }
#         ],
#         "frozen" : false
#     },
#     "name" : "classmate",
#     "weight" : 1.0
# }
# {
#     "class" : "State",
#     "distribution" : {
#         "class" : "Distribution",
#         "dtype" : "str",
#         "name" : "DiscreteDistribution",
#         "parameters" : [
#             {
#                 "\uff0c" : 0.9117647058823529,
#                 "\u3001" : 0.058823529411764705,
#                 "," : 0.029411764705882353
#             }
#         ],
#         "frozen" : false
#     },
#     "name" : ",",
#     "weight" : 1.0
# }
# {
#     "class" : "State",
#     "distribution" : {
#         "class" : "Distribution",
#         "dtype" : "str",
#         "name" : "DiscreteDistribution",
#         "parameters" : [
#             {
#                 "\u5979" : 1.0
#             }
#         ],
#         "frozen" : false
#     },
#     "name" : "she",
#     "weight" : 1.0
# }
# {
#     "class" : "State",
#     "distribution" : {
#         "class" : "Distribution",
#         "dtype" : "str",
#         "name" : "DiscreteDistribution",
#         "parameters" : [
#             {
#                 "\u4e0d\u5149" : 0.5,
#                 "\u4e0d\u4ec5" : 0.5
#             }
#         ],
#         "frozen" : false
#     },
#     "name" : "not only",
#     "weight" : 1.0
# }
# {
#     "class" : "State",
#     "distribution" : {
#         "class" : "Distribution",
#         "dtype" : "str",
#         "name" : "DiscreteDistribution",
#         "parameters" : [
#             {
#                 "\u5b66\u4e60" : 1.0
#             }
#         ],
#         "frozen" : false
#     },
#     "name" : "study",
#     "weight" : 1.0
# }
# {
#     "class" : "State",
#     "distribution" : {
#         "class" : "Distribution",
#         "dtype" : "str",
#         "name" : "DiscreteDistribution",
#         "parameters" : [
#             {
#                 "\u662f" : 0.3333333333333333,
#                 "\u8fd8\u662f" : 0.16666666666666666,
#                 "\u5c31\u662f" : 0.5
#             }
#         ],
#         "frozen" : false
#     },
#     "name" : "is",
#     "weight" : 1.0
# }
# {
#     "class" : "State",
#     "distribution" : {
#         "class" : "Distribution",
#         "dtype" : "str",
#         "name" : "DiscreteDistribution",
#         "parameters" : [
#             {
#                 "\u7b2c\u4e00\u540d" : 1.0
#             }
#         ],
#         "frozen" : false
#     },
#     "name" : "first-class",
#     "weight" : 1.0
# }
# {
#     "class" : "State",
#     "distribution" : {
#         "class" : "Distribution",
#         "dtype" : "str",
#         "name" : "DiscreteDistribution",
#         "parameters" : [
#             {
#                 "\u800c\u4e14" : 0.5,
#                 "\u548c" : 0.5
#             }
#         ],
#         "frozen" : false
#     },
#     "name" : "and",
#     "weight" : 1.0
# }
# {
#     "class" : "State",
#     "distribution" : {
#         "class" : "Distribution",
#         "dtype" : "str",
#         "name" : "DiscreteDistribution",
#         "parameters" : [
#             {
#                 "\u5728" : 0.3333333333333333,
#                 "\u91cc" : 0.3333333333333333,
#                 "\u88c5\u5728" : 0.3333333333333333
#             }
#         ],
#         "frozen" : false
#     },
#     "name" : "in",
#     "weight" : 1.0
# }
# {
#     "class" : "State",
#     "distribution" : {
#         "class" : "Distribution",
#         "dtype" : "str",
#         "name" : "DiscreteDistribution",
#         "parameters" : [
#             {
#                 "\u7ecf\u5e38" : 1.0
#             }
#         ],
#         "frozen" : false
#     },
#     "name" : "usually",
#     "weight" : 1.0
# }
# {
#     "class" : "State",
#     "distribution" : {
#         "class" : "Distribution",
#         "dtype" : "str",
#         "name" : "DiscreteDistribution",
#         "parameters" : [
#             {
#                 "\u53d7" : 1.0
#             }
#         ],
#         "frozen" : false
#     },
#     "name" : "been",
#     "weight" : 1.0
# }
# {
#     "class" : "State",
#     "distribution" : {
#         "class" : "Distribution",
#         "dtype" : "str",
#         "name" : "DiscreteDistribution",
#         "parameters" : [
#             {
#                 "\u8868\u626c\u7684" : 1.0
#             }
#         ],
#         "frozen" : false
#     },
#     "name" : "Praise",
#     "weight" : 1.0
# }
# {
#     "class" : "State",
#     "distribution" : {
#         "class" : "Distribution",
#         "dtype" : "str",
#         "name" : "DiscreteDistribution",
#         "parameters" : [
#             {
#                 "\u4eba\u7269" : 1.0
#             }
#         ],
#         "frozen" : false
#     },
#     "name" : "character",
#     "weight" : 1.0
# }
# {
#     "class" : "State",
#     "distribution" : {
#         "class" : "Distribution",
#         "dtype" : "str",
#         "name" : "DiscreteDistribution",
#         "parameters" : [
#             {
#                 "\u590f\u5b87" : 1.0
#             }
#         ],
#         "frozen" : false
#     },
#     "name" : "xiayu",
#     "weight" : 1.0
# }
# {
#     "class" : "State",
#     "distribution" : {
#         "class" : "Distribution",
#         "dtype" : "str",
#         "name" : "DiscreteDistribution",
#         "parameters" : [
#             {
#                 "\u5b66\u751f" : 0.4,
#                 "\u540c\u5b66\u4eec" : 0.2,
#                 "\u540c\u5b66" : 0.4
#             }
#         ],
#         "frozen" : false
#     },
#     "name" : "student",
#     "weight" : 1.0
# }
# {
#     "class" : "State",
#     "distribution" : {
#         "class" : "Distribution",
#         "dtype" : "str",
#         "name" : "DiscreteDistribution",
#         "parameters" : [
#             {
#                 "\u6bcf\u5e74\u7684" : 1.0
#             }
#         ],
#         "frozen" : false
#     },
#     "name" : "annual",
#     "weight" : 1.0
# }
# {
#     "class" : "State",
#     "distribution" : {
#         "class" : "Distribution",
#         "dtype" : "str",
#         "name" : "DiscreteDistribution",
#         "parameters" : [
#             {
#                 "\u8fd8" : 0.25,
#                 "\u8fd8\u6709" : 0.25,
#                 "\u4e5f\u8981" : 0.25,
#                 "\u4e5f" : 0.25
#             }
#         ],
#         "frozen" : false
#     },
#     "name" : "also",
#     "weight" : 1.0
# }
# {
#     "class" : "State",
#     "distribution" : {
#         "class" : "Distribution",
#         "dtype" : "str",
#         "name" : "DiscreteDistribution",
#         "parameters" : [
#             {
#                 "\u70ed\u7231" : 1.0
#             }
#         ],
#         "frozen" : false
#     },
#     "name" : "like",
#     "weight" : 1.0
# }
# {
#     "class" : "State",
#     "distribution" : {
#         "class" : "Distribution",
#         "dtype" : "str",
#         "name" : "DiscreteDistribution",
#         "parameters" : [
#             {
#                 "\u96c6\u4f53" : 1.0
#             }
#         ],
#         "frozen" : false
#     },
#     "name" : "collective",
#     "weight" : 1.0
# }
# {
#     "class" : "State",
#     "distribution" : {
#         "class" : "Distribution",
#         "dtype" : "str",
#         "name" : "DiscreteDistribution",
#         "parameters" : [
#             {
#                 "\u6628\u5929" : 1.0
#             }
#         ],
#         "frozen" : false
#     },
#     "name" : "yesterday",
#     "weight" : 1.0
# }
# {
#     "class" : "State",
#     "distribution" : {
#         "class" : "Distribution",
#         "dtype" : "str",
#         "name" : "DiscreteDistribution",
#         "parameters" : [
#             {
#                 "\u653e\u5b66\u7684" : 1.0
#             }
#         ],
#         "frozen" : false
#     },
#     "name" : "after school",
#     "weight" : 1.0
# }
# {
#     "class" : "State",
#     "distribution" : {
#         "class" : "Distribution",
#         "dtype" : "str",
#         "name" : "DiscreteDistribution",
#         "parameters" : [
#             {
#                 "\u65f6\u5019" : 1.0
#             }
#         ],
#         "frozen" : false
#     },
#     "name" : "time",
#     "weight" : 1.0
# }
# {
#     "class" : "State",
#     "distribution" : {
#         "class" : "Distribution",
#         "dtype" : "str",
#         "name" : "DiscreteDistribution",
#         "parameters" : [
#             {
#                 "\u542c\u5230" : 1.0
#             }
#         ],
#         "frozen" : false
#     },
#     "name" : "hear",
#     "weight" : 1.0
# }
# {
#     "class" : "State",
#     "distribution" : {
#         "class" : "Distribution",
#         "dtype" : "str",
#         "name" : "DiscreteDistribution",
#         "parameters" : [
#             {
#                 "\u94c3\u58f0" : 1.0
#             }
#         ],
#         "frozen" : false
#     },
#     "name" : "ring bell",
#     "weight" : 1.0
# }
# {
#     "class" : "State",
#     "distribution" : {
#         "class" : "Distribution",
#         "dtype" : "str",
#         "name" : "DiscreteDistribution",
#         "parameters" : [
#             {
#                 "\u4e00\u7a9d\u8702\u7684" : 1.0
#             }
#         ],
#         "frozen" : false
#     },
#     "name" : "a lot",
#     "weight" : 1.0
# }
# {
#     "class" : "State",
#     "distribution" : {
#         "class" : "Distribution",
#         "dtype" : "str",
#         "name" : "DiscreteDistribution",
#         "parameters" : [
#             {
#                 "\u90fd" : 1.0
#             }
#         ],
#         "frozen" : false
#     },
#     "name" : "all",
#     "weight" : 1.0
# }
# {
#     "class" : "State",
#     "distribution" : {
#         "class" : "Distribution",
#         "dtype" : "str",
#         "name" : "DiscreteDistribution",
#         "parameters" : [
#             {
#                 "\u51fa\u53bb" : 1.0
#             }
#         ],
#         "frozen" : false
#     },
#     "name" : "get out",
#     "weight" : 1.0
# }
# {
#     "class" : "State",
#     "distribution" : {
#         "class" : "Distribution",
#         "dtype" : "str",
#         "name" : "DiscreteDistribution",
#         "parameters" : [
#             {
#                 "\u5ffd\u7136" : 1.0
#             }
#         ],
#         "frozen" : false
#     },
#     "name" : "suddently",
#     "weight" : 1.0
# }
# {
#     "class" : "State",
#     "distribution" : {
#         "class" : "Distribution",
#         "dtype" : "str",
#         "name" : "DiscreteDistribution",
#         "parameters" : [
#             {
#                 "\u505c\u4e0b" : 1.0
#             }
#         ],
#         "frozen" : false
#     },
#     "name" : "stop",
#     "weight" : 1.0
# }
# {
#     "class" : "State",
#     "distribution" : {
#         "class" : "Distribution",
#         "dtype" : "str",
#         "name" : "DiscreteDistribution",
#         "parameters" : [
#             {
#                 "\u811a\u6b65" : 1.0
#             }
#         ],
#         "frozen" : false
#     },
#     "name" : "pace",
#     "weight" : 1.0
# }
# {
#     "class" : "State",
#     "distribution" : {
#         "class" : "Distribution",
#         "dtype" : "str",
#         "name" : "DiscreteDistribution",
#         "parameters" : [
#             {
#                 "\u6211" : 1.0
#             }
#         ],
#         "frozen" : false
#     },
#     "name" : "I",
#     "weight" : 1.0
# }
# {
#     "class" : "State",
#     "distribution" : {
#         "class" : "Distribution",
#         "dtype" : "str",
#         "name" : "DiscreteDistribution",
#         "parameters" : [
#             {
#                 "\u987a\u7740" : 1.0
#             }
#         ],
#         "frozen" : false
#     },
#     "name" : "along",
#     "weight" : 1.0
# }
# {
#     "class" : "State",
#     "distribution" : {
#         "class" : "Distribution",
#         "dtype" : "str",
#         "name" : "DiscreteDistribution",
#         "parameters" : [
#             {
#                 "\u5979\u7684" : 1.0
#             }
#         ],
#         "frozen" : false
#     },
#     "name" : "hers",
#     "weight" : 1.0
# }
# {
#     "class" : "State",
#     "distribution" : {
#         "class" : "Distribution",
#         "dtype" : "str",
#         "name" : "DiscreteDistribution",
#         "parameters" : [
#             {
#                 "\u76ee\u5149" : 1.0
#             }
#         ],
#         "frozen" : false
#     },
#     "name" : "eye",
#     "weight" : 1.0
# }
# {
#     "class" : "State",
#     "distribution" : {
#         "class" : "Distribution",
#         "dtype" : "str",
#         "name" : "DiscreteDistribution",
#         "parameters" : [
#             {
#                 "\u770b\u89c1" : 1.0
#             }
#         ],
#         "frozen" : false
#     },
#     "name" : "see",
#     "weight" : 1.0
# }
# {
#     "class" : "State",
#     "distribution" : {
#         "class" : "Distribution",
#         "dtype" : "str",
#         "name" : "DiscreteDistribution",
#         "parameters" : [
#             {
#                 "\u6742\u4e71" : 1.0
#             }
#         ],
#         "frozen" : false
#     },
#     "name" : "massly",
#     "weight" : 1.0
# }
# {
#     "class" : "State",
#     "distribution" : {
#         "class" : "Distribution",
#         "dtype" : "str",
#         "name" : "DiscreteDistribution",
#         "parameters" : [
#             {
#                 "\u5730\u4e0a" : 1.0
#             }
#         ],
#         "frozen" : false
#     },
#     "name" : "ground",
#     "weight" : 1.0
# }
# {
#     "class" : "State",
#     "distribution" : {
#         "class" : "Distribution",
#         "dtype" : "str",
#         "name" : "DiscreteDistribution",
#         "parameters" : [
#             {
#                 "\u4e00\u5927\u5806" : 1.0
#             }
#         ],
#         "frozen" : false
#     },
#     "name" : "a load of",
#     "weight" : 1.0
# }
# {
#     "class" : "State",
#     "distribution" : {
#         "class" : "Distribution",
#         "dtype" : "str",
#         "name" : "DiscreteDistribution",
#         "parameters" : [
#             {
#                 "\u7559\u4e0b\u7684" : 1.0
#             }
#         ],
#         "frozen" : false
#     },
#     "name" : "left",
#     "weight" : 1.0
# }
# {
#     "class" : "State",
#     "distribution" : {
#         "class" : "Distribution",
#         "dtype" : "str",
#         "name" : "DiscreteDistribution",
#         "parameters" : [
#             {
#                 "\u7eb8\u5c51" : 1.0
#             }
#         ],
#         "frozen" : false
#     },
#     "name" : "paper",
#     "weight" : 1.0
# }
# {
#     "class" : "State",
#     "distribution" : {
#         "class" : "Distribution",
#         "dtype" : "str",
#         "name" : "DiscreteDistribution",
#         "parameters" : [
#             {
#                 "\u6211\u4eec" : 1.0
#             }
#         ],
#         "frozen" : false
#     },
#     "name" : "we",
#     "weight" : 1.0
# }
# {
#     "class" : "State",
#     "distribution" : {
#         "class" : "Distribution",
#         "dtype" : "str",
#         "name" : "DiscreteDistribution",
#         "parameters" : [
#             {
#                 "\u626b\u5730" : 0.3333333333333333,
#                 "\u6253\u626b" : 0.3333333333333333,
#                 "\u6536\u62fe" : 0.3333333333333333
#             }
#         ],
#         "frozen" : false
#     },
#     "name" : "clean",
#     "weight" : 1.0
# }
# {
#     "class" : "State",
#     "distribution" : {
#         "class" : "Distribution",
#         "dtype" : "str",
#         "name" : "DiscreteDistribution",
#         "parameters" : [
#             {
#                 "\u6446" : 0.5,
#                 "\u628a" : 0.5
#             }
#         ],
#         "frozen" : false
#     },
#     "name" : "place",
#     "weight" : 1.0
# }
# {
#     "class" : "State",
#     "distribution" : {
#         "class" : "Distribution",
#         "dtype" : "str",
#         "name" : "DiscreteDistribution",
#         "parameters" : [
#             {
#                 "\u5c0f\u684c\u5b50" : 1.0
#             }
#         ],
#         "frozen" : false
#     },
#     "name" : "table",
#     "weight" : 1.0
# }
# {
#     "class" : "State",
#     "distribution" : {
#         "class" : "Distribution",
#         "dtype" : "str",
#         "name" : "DiscreteDistribution",
#         "parameters" : [
#             {
#                 "\u64e6" : 1.0
#             }
#         ],
#         "frozen" : false
#     },
#     "name" : "wipe",
#     "weight" : 1.0
# }
# {
#     "class" : "State",
#     "distribution" : {
#         "class" : "Distribution",
#         "dtype" : "str",
#         "name" : "DiscreteDistribution",
#         "parameters" : [
#             {
#                 "\u9ed1\u677f" : 1.0
#             }
#         ],
#         "frozen" : false
#     },
#     "name" : "blackboard",
#     "weight" : 1.0
# }
# {
#     "class" : "State",
#     "distribution" : {
#         "class" : "Distribution",
#         "dtype" : "str",
#         "name" : "DiscreteDistribution",
#         "parameters" : [
#             {
#                 "\u5fd9" : 1.0
#             }
#         ],
#         "frozen" : false
#     },
#     "name" : "busy",
#     "weight" : 1.0
# }
# {
#     "class" : "State",
#     "distribution" : {
#         "class" : "Distribution",
#         "dtype" : "str",
#         "name" : "DiscreteDistribution",
#         "parameters" : [
#             {
#                 "\u8fc7\u4e86" : 1.0
#             }
#         ],
#         "frozen" : false
#     },
#     "name" : "after",
#     "weight" : 1.0
# }
# {
#     "class" : "State",
#     "distribution" : {
#         "class" : "Distribution",
#         "dtype" : "str",
#         "name" : "DiscreteDistribution",
#         "parameters" : [
#             {
#                 "\u4e00\u4f1a\u513f" : 1.0
#             }
#         ],
#         "frozen" : false
#     },
#     "name" : "a while",
#     "weight" : 1.0
# }
# {
#     "class" : "State",
#     "distribution" : {
#         "class" : "Distribution",
#         "dtype" : "str",
#         "name" : "DiscreteDistribution",
#         "parameters" : [
#             {
#                 "\u7ec8\u4e8e" : 1.0
#             }
#         ],
#         "frozen" : false
#     },
#     "name" : "finally",
#     "weight" : 1.0
# }
# {
#     "class" : "State",
#     "distribution" : {
#         "class" : "Distribution",
#         "dtype" : "str",
#         "name" : "DiscreteDistribution",
#         "parameters" : [
#             {
#                 "\u5b8c\u4e86" : 1.0
#             }
#         ],
#         "frozen" : false
#     },
#     "name" : "finish",
#     "weight" : 1.0
# }
# {
#     "class" : "State",
#     "distribution" : {
#         "class" : "Distribution",
#         "dtype" : "str",
#         "name" : "DiscreteDistribution",
#         "parameters" : [
#             {
#                 "\u5783\u573e" : 1.0
#             }
#         ],
#         "frozen" : false
#     },
#     "name" : "garbage",
#     "weight" : 1.0
# }
# {
#     "class" : "State",
#     "distribution" : {
#         "class" : "Distribution",
#         "dtype" : "str",
#         "name" : "DiscreteDistribution",
#         "parameters" : [
#             {
#                 "\u888b\u5b50" : 1.0
#             }
#         ],
#         "frozen" : false
#     },
#     "name" : "bag",
#     "weight" : 1.0
# }
# {
#     "class" : "State",
#     "distribution" : {
#         "class" : "Distribution",
#         "dtype" : "str",
#         "name" : "DiscreteDistribution",
#         "parameters" : [
#             {
#                 "\u548c" : 0.5,
#                 "\u5e26\u7740" : 0.5
#             }
#         ],
#         "frozen" : false
#     },
#     "name" : "with",
#     "weight" : 1.0
# }
# {
#     "class" : "State",
#     "distribution" : {
#         "class" : "Distribution",
#         "dtype" : "str",
#         "name" : "DiscreteDistribution",
#         "parameters" : [
#             {
#                 "\u6211" : 1.0
#             }
#         ],
#         "frozen" : false
#     },
#     "name" : "me",
#     "weight" : 1.0
# }
# {
#     "class" : "State",
#     "distribution" : {
#         "class" : "Distribution",
#         "dtype" : "str",
#         "name" : "DiscreteDistribution",
#         "parameters" : [
#             {
#                 "\u8d70\u51fa" : 1.0
#             }
#         ],
#         "frozen" : false
#     },
#     "name" : "go out",
#     "weight" : 1.0
# }
# {
#     "class" : "State",
#     "distribution" : {
#         "class" : "Distribution",
#         "dtype" : "str",
#         "name" : "DiscreteDistribution",
#         "parameters" : [
#             {
#                 "\u5173\u597d" : 1.0
#             }
#         ],
#         "frozen" : false
#     },
#     "name" : "close",
#     "weight" : 1.0
# }
# {
#     "class" : "State",
#     "distribution" : {
#         "class" : "Distribution",
#         "dtype" : "str",
#         "name" : "DiscreteDistribution",
#         "parameters" : [
#             {
#                 "\u95e8" : 1.0
#             }
#         ],
#         "frozen" : false
#     },
#     "name" : "door",
#     "weight" : 1.0
# }
# {
#     "class" : "State",
#     "distribution" : {
#         "class" : "Distribution",
#         "dtype" : "str",
#         "name" : "DiscreteDistribution",
#         "parameters" : [
#             {
#                 "\u53bb" : 0.6666666666666666,
#                 "\u4e70" : 0.3333333333333333
#             }
#         ],
#         "frozen" : false
#     },
#     "name" : "go",
#     "weight" : 1.0
# }
# {
#     "class" : "State",
#     "distribution" : {
#         "class" : "Distribution",
#         "dtype" : "str",
#         "name" : "DiscreteDistribution",
#         "parameters" : [
#             {
#                 "\u6254" : 1.0
#             }
#         ],
#         "frozen" : false
#     },
#     "name" : "throw",
#     "weight" : 1.0
# }
# {
#     "class" : "State",
#     "distribution" : {
#         "class" : "Distribution",
#         "dtype" : "str",
#         "name" : "DiscreteDistribution",
#         "parameters" : [
#             {
#                 "\u7531\u4e8e" : 0.5,
#                 "\u56e0\u4e3a" : 0.5
#             }
#         ],
#         "frozen" : false
#     },
#     "name" : "because",
#     "weight" : 1.0
# }
# {
#     "class" : "State",
#     "distribution" : {
#         "class" : "Distribution",
#         "dtype" : "str",
#         "name" : "DiscreteDistribution",
#         "parameters" : [
#             {
#                 "\u8dd1\u5f97" : 1.0
#             }
#         ],
#         "frozen" : false
#     },
#     "name" : "run",
#     "weight" : 1.0
# }
# {
#     "class" : "State",
#     "distribution" : {
#         "class" : "Distribution",
#         "dtype" : "str",
#         "name" : "DiscreteDistribution",
#         "parameters" : [
#             {
#                 "\u592a" : 1.0
#             }
#         ],
#         "frozen" : false
#     },
#     "name" : "too",
#     "weight" : 1.0
# }
# {
#     "class" : "State",
#     "distribution" : {
#         "class" : "Distribution",
#         "dtype" : "str",
#         "name" : "DiscreteDistribution",
#         "parameters" : [
#             {
#                 "\u5feb" : 1.0
#             }
#         ],
#         "frozen" : false
#     },
#     "name" : "fast",
#     "weight" : 1.0
# }
# {
#     "class" : "State",
#     "distribution" : {
#         "class" : "Distribution",
#         "dtype" : "str",
#         "name" : "DiscreteDistribution",
#         "parameters" : [
#             {
#                 "\u4e0d\u5c0f\u5fc3" : 1.0
#             }
#         ],
#         "frozen" : false
#     },
#     "name" : "incaution",
#     "weight" : 1.0
# }
# {
#     "class" : "State",
#     "distribution" : {
#         "class" : "Distribution",
#         "dtype" : "str",
#         "name" : "DiscreteDistribution",
#         "parameters" : [
#             {
#                 "\u6454\u5012\u4e86" : 1.0
#             }
#         ],
#         "frozen" : false
#     },
#     "name" : "fell",
#     "weight" : 1.0
# }
# {
#     "class" : "State",
#     "distribution" : {
#         "class" : "Distribution",
#         "dtype" : "str",
#         "name" : "DiscreteDistribution",
#         "parameters" : [
#             {
#                 "\u8fdc\u8fdc\u5730" : 1.0
#             }
#         ],
#         "frozen" : false
#     },
#     "name" : "far away",
#     "weight" : 1.0
# }
# {
#     "class" : "State",
#     "distribution" : {
#         "class" : "Distribution",
#         "dtype" : "str",
#         "name" : "DiscreteDistribution",
#         "parameters" : [
#             {
#                 "\u8138\u4e0a" : 1.0
#             }
#         ],
#         "frozen" : false
#     },
#     "name" : "face",
#     "weight" : 1.0
# }
# {
#     "class" : "State",
#     "distribution" : {
#         "class" : "Distribution",
#         "dtype" : "str",
#         "name" : "DiscreteDistribution",
#         "parameters" : [
#             {
#                 "\u75db\u82e6\u7684" : 1.0
#             }
#         ],
#         "frozen" : false
#     },
#     "name" : "painful",
#     "weight" : 1.0
# }
# {
#     "class" : "State",
#     "distribution" : {
#         "class" : "Distribution",
#         "dtype" : "str",
#         "name" : "DiscreteDistribution",
#         "parameters" : [
#             {
#                 "\u8868\u60c5" : 1.0
#             }
#         ],
#         "frozen" : false
#     },
#     "name" : "expression",
#     "weight" : 1.0
# }
# {
#     "class" : "State",
#     "distribution" : {
#         "class" : "Distribution",
#         "dtype" : "str",
#         "name" : "DiscreteDistribution",
#         "parameters" : [
#             {
#                 "\u7ad9\u4e86" : 1.0
#             }
#         ],
#         "frozen" : false
#     },
#     "name" : "stand",
#     "weight" : 1.0
# }
# {
#     "class" : "State",
#     "distribution" : {
#         "class" : "Distribution",
#         "dtype" : "str",
#         "name" : "DiscreteDistribution",
#         "parameters" : [
#             {
#                 "\u8d77\u6765" : 1.0
#             }
#         ],
#         "frozen" : false
#     },
#     "name" : "up",
#     "weight" : 1.0
# }
# {
#     "class" : "State",
#     "distribution" : {
#         "class" : "Distribution",
#         "dtype" : "str",
#         "name" : "DiscreteDistribution",
#         "parameters" : [
#             {
#                 "\u63c9\u4e86\u63c9" : 1.0
#             }
#         ],
#         "frozen" : false
#     },
#     "name" : "knead",
#     "weight" : 1.0
# }
# {
#     "class" : "State",
#     "distribution" : {
#         "class" : "Distribution",
#         "dtype" : "str",
#         "name" : "DiscreteDistribution",
#         "parameters" : [
#             {
#                 "\u819d\u76d6" : 1.0
#             }
#         ],
#         "frozen" : false
#     },
#     "name" : "knee",
#     "weight" : 1.0
# }
# {
#     "class" : "State",
#     "distribution" : {
#         "class" : "Distribution",
#         "dtype" : "str",
#         "name" : "DiscreteDistribution",
#         "parameters" : [
#             {
#                 "\u575a\u6301" : 1.0
#             }
#         ],
#         "frozen" : false
#     },
#     "name" : "insist",
#     "weight" : 1.0
# }
# {
#     "class" : "State",
#     "distribution" : {
#         "class" : "Distribution",
#         "dtype" : "str",
#         "name" : "DiscreteDistribution",
#         "parameters" : [
#             {
#                 "\u628a" : 1.0
#             }
#         ],
#         "frozen" : false
#     },
#     "name" : "hold",
#     "weight" : 1.0
# }
# {
#     "class" : "State",
#     "distribution" : {
#         "class" : "Distribution",
#         "dtype" : "str",
#         "name" : "DiscreteDistribution",
#         "parameters" : [
#             {
#                 "\u6254\u6389" : 1.0
#             }
#         ],
#         "frozen" : false
#     },
#     "name" : "throw away",
#     "weight" : 1.0
# }
# {
#     "class" : "State",
#     "distribution" : {
#         "class" : "Distribution",
#         "dtype" : "str",
#         "name" : "DiscreteDistribution",
#         "parameters" : [
#             {
#                 "\u624d" : 0.5,
#                 "\u5c31\u53bb" : 0.5
#             }
#         ],
#         "frozen" : false
#     },
#     "name" : "just",
#     "weight" : 1.0
# }
# {
#     "class" : "State",
#     "distribution" : {
#         "class" : "Distribution",
#         "dtype" : "str",
#         "name" : "DiscreteDistribution",
#         "parameters" : [
#             {
#                 "\u4e1c\u897f" : 1.0
#             }
#         ],
#         "frozen" : false
#     },
#     "name" : "thing",
#     "weight" : 1.0
# }
# {
#     "class" : "State",
#     "distribution" : {
#         "class" : "Distribution",
#         "dtype" : "str",
#         "name" : "DiscreteDistribution",
#         "parameters" : [
#             {
#                 "\u56de" : 1.0
#             }
#         ],
#         "frozen" : false
#     },
#     "name" : "back",
#     "weight" : 1.0
# }
# {
#     "class" : "State",
#     "distribution" : {
#         "class" : "Distribution",
#         "dtype" : "str",
#         "name" : "DiscreteDistribution",
#         "parameters" : [
#             {
#                 "\u5bb6" : 1.0
#             }
#         ],
#         "frozen" : false
#     },
#     "name" : "home",
#     "weight" : 1.0
# }
# {
#     "class" : "State",
#     "distribution" : {
#         "class" : "Distribution",
#         "dtype" : "str",
#         "name" : "DiscreteDistribution",
#         "parameters" : [
#             {
#                 "\u8fd9" : 1.0
#             }
#         ],
#         "frozen" : false
#     },
#     "name" : "this",
#     "weight" : 1.0
# }
# {
#     "class" : "State",
#     "distribution" : {
#         "class" : "Distribution",
#         "dtype" : "str",
#         "name" : "DiscreteDistribution",
#         "parameters" : [
#             {
#                 "\u5411" : 1.0
#             }
#         ],
#         "frozen" : false
#     },
#     "name" : "from",
#     "weight" : 1.0
# }
# {
#     "class" : "State",
#     "distribution" : {
#         "class" : "Distribution",
#         "dtype" : "str",
#         "name" : "DiscreteDistribution",
#         "parameters" : [
#             {
#                 "\u5979" : 1.0
#             }
#         ],
#         "frozen" : false
#     },
#     "name" : "her",
#     "weight" : 1.0
# }
# {
#     "class" : "State",
#     "distribution" : {
#         "class" : "Distribution",
#         "dtype" : "str",
#         "name" : "DiscreteDistribution",
#         "parameters" : [
#             {
#                 "\u8981" : 1.0
#             }
#         ],
#         "frozen" : false
#     },
#     "name" : "want",
#     "weight" : 1.0
# }
# {
#     "class" : "State",
#     "distribution" : {
#         "class" : "Distribution",
#         "dtype" : "str",
#         "name" : "DiscreteDistribution",
#         "parameters" : [
#             {
#                 "\u597d\u597d" : 1.0
#             }
#         ],
#         "frozen" : false
#     },
#     "name" : "well",
#     "weight" : 1.0
# }
# {
#     "class" : "State",
#     "distribution" : {
#         "class" : "Distribution",
#         "dtype" : "str",
#         "name" : "DiscreteDistribution",
#         "parameters" : [
#             {
#                 "\u66f4\u8981" : 1.0
#             }
#         ],
#         "frozen" : false
#     },
#     "name" : "more",
#     "weight" : 1.0
# }
# {
#     "class" : "State",
#     "distribution" : {
#         "class" : "Distribution",
#         "dtype" : "str",
#         "name" : "DiscreteDistribution",
#         "parameters" : [
#             {
#                 "\u7231\u62a4" : 1.0
#             }
#         ],
#         "frozen" : false
#     },
#     "name" : "care",
#     "weight" : 1.0
# }
# {
#     "class" : "State",
#     "distribution" : {
#         "class" : "Distribution",
#         "dtype" : "str",
#         "name" : "DiscreteDistribution",
#         "parameters" : [
#             {
#                 "\u4e09\u6708" : 1.0
#             }
#         ],
#         "frozen" : false
#     },
#     "name" : "march",
#     "weight" : 1.0
# }
# {
#     "class" : "State",
#     "distribution" : {
#         "class" : "Distribution",
#         "dtype" : "str",
#         "name" : "DiscreteDistribution",
#         "parameters" : [
#             {
#                 "\u5230\u4e86" : 1.0
#             }
#         ],
#         "frozen" : false
#     },
#     "name" : "arrived",
#     "weight" : 1.0
# }
# {
#     "class" : "State",
#     "distribution" : {
#         "class" : "Distribution",
#         "dtype" : "str",
#         "name" : "DiscreteDistribution",
#         "parameters" : [
#             {
#                 "\u6625" : 1.0
#             }
#         ],
#         "frozen" : false
#     },
#     "name" : "spring",
#     "weight" : 1.0
# }
# {
#     "class" : "State",
#     "distribution" : {
#         "class" : "Distribution",
#         "dtype" : "str",
#         "name" : "DiscreteDistribution",
#         "parameters" : [
#             {
#                 "\u59d1\u5a18" : 1.0
#             }
#         ],
#         "frozen" : false
#     },
#     "name" : "girl",
#     "weight" : 1.0
# }
# {
#     "class" : "State",
#     "distribution" : {
#         "class" : "Distribution",
#         "dtype" : "str",
#         "name" : "DiscreteDistribution",
#         "parameters" : [
#             {
#                 "\u6084\u6084\u7684" : 1.0
#             }
#         ],
#         "frozen" : false
#     },
#     "name" : "quietly",
#     "weight" : 1.0
# }
# {
#     "class" : "State",
#     "distribution" : {
#         "class" : "Distribution",
#         "dtype" : "str",
#         "name" : "DiscreteDistribution",
#         "parameters" : [
#             {
#                 "\u6765\u5230\u4e86" : 1.0
#             }
#         ],
#         "frozen" : false
#     },
#     "name" : "arrive",
#     "weight" : 1.0
# }
# {
#     "class" : "State",
#     "distribution" : {
#         "class" : "Distribution",
#         "dtype" : "str",
#         "name" : "DiscreteDistribution",
#         "parameters" : [
#             {
#                 "\u8eab\u8fb9" : 1.0
#             }
#         ],
#         "frozen" : false
#     },
#     "name" : "side",
#     "weight" : 1.0
# }
# {
#     "class" : "State",
#     "distribution" : {
#         "class" : "Distribution",
#         "dtype" : "str",
#         "name" : "DiscreteDistribution",
#         "parameters" : [
#             {
#                 "\u8f7b\u624b\u8f7b\u811a" : 1.0
#             }
#         ],
#         "frozen" : false
#     },
#     "name" : "lightly",
#     "weight" : 1.0
# }
# {
#     "class" : "State",
#     "distribution" : {
#         "class" : "Distribution",
#         "dtype" : "str",
#         "name" : "DiscreteDistribution",
#         "parameters" : [
#             {
#                 "\u6084\u6084\u7684" : 1.0
#             }
#         ],
#         "frozen" : false
#     },
#     "name" : "silent",
#     "weight" : 1.0
# }
# {
#     "class" : "State",
#     "distribution" : {
#         "class" : "Distribution",
#         "dtype" : "str",
#         "name" : "DiscreteDistribution",
#         "parameters" : [
#             {
#                 "\u8d70\u7740" : 1.0
#             }
#         ],
#         "frozen" : false
#     },
#     "name" : "walking",
#     "weight" : 1.0
# }
# {
#     "class" : "State",
#     "distribution" : {
#         "class" : "Distribution",
#         "dtype" : "str",
#         "name" : "DiscreteDistribution",
#         "parameters" : [
#             {
#                 "\u6d51\u8eab" : 1.0
#             }
#         ],
#         "frozen" : false
#     },
#     "name" : "whole body",
#     "weight" : 1.0
# }
# {
#     "class" : "State",
#     "distribution" : {
#         "class" : "Distribution",
#         "dtype" : "str",
#         "name" : "DiscreteDistribution",
#         "parameters" : [
#             {
#                 "\u6563\u53d1\u7740" : 1.0
#             }
#         ],
#         "frozen" : false
#     },
#     "name" : "exude",
#     "weight" : 1.0
# }
# {
#     "class" : "State",
#     "distribution" : {
#         "class" : "Distribution",
#         "dtype" : "str",
#         "name" : "DiscreteDistribution",
#         "parameters" : [
#             {
#                 "\u6e05\u9999" : 1.0
#             }
#         ],
#         "frozen" : false
#     },
#     "name" : "fragrance",
#     "weight" : 1.0
# }
# {
#     "class" : "State",
#     "distribution" : {
#         "class" : "Distribution",
#         "dtype" : "str",
#         "name" : "DiscreteDistribution",
#         "parameters" : [
#             {
#                 "\u7f9e\u6da9\u5730" : 1.0
#             }
#         ],
#         "frozen" : false
#     },
#     "name" : "shyly",
#     "weight" : 1.0
# }
# {
#     "class" : "State",
#     "distribution" : {
#         "class" : "Distribution",
#         "dtype" : "str",
#         "name" : "DiscreteDistribution",
#         "parameters" : [
#             {
#                 "\u6709\u4e00\u5929" : 1.0
#             }
#         ],
#         "frozen" : false
#     },
#     "name" : "one day",
#     "weight" : 1.0
# }
# {
#     "class" : "State",
#     "distribution" : {
#         "class" : "Distribution",
#         "dtype" : "str",
#         "name" : "DiscreteDistribution",
#         "parameters" : [
#             {
#                 "\u5988\u5988" : 1.0
#             }
#         ],
#         "frozen" : false
#     },
#     "name" : "mom",
#     "weight" : 1.0
# }
# {
#     "class" : "State",
#     "distribution" : {
#         "class" : "Distribution",
#         "dtype" : "str",
#         "name" : "DiscreteDistribution",
#         "parameters" : [
#             {
#                 "\u53eb" : 1.0
#             }
#         ],
#         "frozen" : false
#     },
#     "name" : "let",
#     "weight" : 1.0
# }
# {
#     "class" : "State",
#     "distribution" : {
#         "class" : "Distribution",
#         "dtype" : "str",
#         "name" : "DiscreteDistribution",
#         "parameters" : [
#             {
#                 "\u4e70" : 1.0
#             }
#         ],
#         "frozen" : false
#     },
#     "name" : "buy",
#     "weight" : 1.0
# }
# {
#     "class" : "State",
#     "distribution" : {
#         "class" : "Distribution",
#         "dtype" : "str",
#         "name" : "DiscreteDistribution",
#         "parameters" : [
#             {
#                 "\u4e1c\u897f" : 1.0
#             }
#         ],
#         "frozen" : false
#     },
#     "name" : "something",
#     "weight" : 1.0
# }
# {
#     "class" : "State",
#     "distribution" : {
#         "class" : "Distribution",
#         "dtype" : "str",
#         "name" : "DiscreteDistribution",
#         "parameters" : [
#             {
#                 "\u5f00\u5fc3\u7684" : 1.0
#             }
#         ],
#         "frozen" : false
#     },
#     "name" : "happily",
#     "weight" : 1.0
# }
# {
#     "class" : "State",
#     "distribution" : {
#         "class" : "Distribution",
#         "dtype" : "str",
#         "name" : "DiscreteDistribution",
#         "parameters" : [
#             {
#                 "\u8bf4" : 1.0
#             }
#         ],
#         "frozen" : false
#     },
#     "name" : "said",
#     "weight" : 1.0
# }
# {
#     "class" : "State",
#     "distribution" : {
#         "class" : "Distribution",
#         "dtype" : "str",
#         "name" : "DiscreteDistribution",
#         "parameters" : [
#             {
#                 "\u597d\u7684" : 1.0
#             }
#         ],
#         "frozen" : false
#     },
#     "name" : "Okay",
#     "weight" : 1.0
# }
# {
#     "class" : "State",
#     "distribution" : {
#         "class" : "Distribution",
#         "dtype" : "str",
#         "name" : "DiscreteDistribution",
#         "parameters" : [
#             {
#                 "\u77e5\u9053\u4e86" : 1.0
#             }
#         ],
#         "frozen" : false
#     },
#     "name" : "know",
#     "weight" : 1.0
# }
# {
#     "class" : "State",
#     "distribution" : {
#         "class" : "Distribution",
#         "dtype" : "str",
#         "name" : "DiscreteDistribution",
#         "parameters" : [
#             {
#                 "\u8bf4\u5b8c" : 1.0
#             }
#         ],
#         "frozen" : false
#     },
#     "name" : "after that",
#     "weight" : 1.0
# }
# {
#     "class" : "State",
#     "distribution" : {
#         "class" : "Distribution",
#         "dtype" : "str",
#         "name" : "DiscreteDistribution",
#         "parameters" : [
#             {
#                 "\u4e1c\u897f\u4e86" : 1.0
#             }
#         ],
#         "frozen" : false
#     },
#     "name" : "shopping",
#     "weight" : 1.0
# }
# {
#     "class" : "State",
#     "distribution" : {
#         "class" : "Distribution",
#         "dtype" : "str",
#         "name" : "DiscreteDistribution",
#         "parameters" : [
#             {
#                 "\u597d\u7684" : 1.0
#             }
#         ],
#         "frozen" : false
#     },
#     "name" : "okay",
#     "weight" : 1.0
# }
# {
#     "class" : "State",
#     "distribution" : {
#         "class" : "Distribution",
#         "dtype" : "str",
#         "name" : "DiscreteDistribution",
#         "parameters" : [
#             {
#                 "\u53d4\u53d4" : 1.0
#             }
#         ],
#         "frozen" : false
#     },
#     "name" : "uncle",
#     "weight" : 1.0
# }
# {
#     "class" : "State",
#     "distribution" : {
#         "class" : "Distribution",
#         "dtype" : "str",
#         "name" : "DiscreteDistribution",
#         "parameters" : [
#             {
#                 "\u5403" : 1.0
#             }
#         ],
#         "frozen" : false
#     },
#     "name" : "eat",
#     "weight" : 1.0
# }
# {
#     "class" : "State",
#     "distribution" : {
#         "class" : "Distribution",
#         "dtype" : "str",
#         "name" : "DiscreteDistribution",
#         "parameters" : [
#             {
#                 "\u4e00" : 1.0
#             }
#         ],
#         "frozen" : false
#     },
#     "name" : "one",
#     "weight" : 1.0
# }
# {
#     "class" : "State",
#     "distribution" : {
#         "class" : "Distribution",
#         "dtype" : "str",
#         "name" : "DiscreteDistribution",
#         "parameters" : [
#             {
#                 "\u82f9\u679c" : 0.5,
#                 "\u6c34\u679c" : 0.5
#             }
#         ],
#         "frozen" : false
#     },
#     "name" : "apple",
#     "weight" : 1.0
# }
# {
#     "class" : "State",
#     "distribution" : {
#         "class" : "Distribution",
#         "dtype" : "str",
#         "name" : "DiscreteDistribution",
#         "parameters" : [
#             {
#                 "\u7231" : 0.2,
#                 "\u559c\u6b22" : 0.8
#             }
#         ],
#         "frozen" : false
#     },
#     "name" : "love",
#     "weight" : 1.0
# }
# {
#     "class" : "State",
#     "distribution" : {
#         "class" : "Distribution",
#         "dtype" : "str",
#         "name" : "DiscreteDistribution",
#         "parameters" : [
#             {
#                 "\u5403" : 1.0
#             }
#         ],
#         "frozen" : false
#     },
#     "name" : "eating",
#     "weight" : 1.0
# }
# {
#     "class" : "State",
#     "distribution" : {
#         "class" : "Distribution",
#         "dtype" : "str",
#         "name" : "DiscreteDistribution",
#         "parameters" : [
#             {
#                 "\u68a8" : 1.0
#             }
#         ],
#         "frozen" : false
#     },
#     "name" : "pears",
#     "weight" : 1.0
# }
# {
#     "class" : "State",
#     "distribution" : {
#         "class" : "Distribution",
#         "dtype" : "str",
#         "name" : "DiscreteDistribution",
#         "parameters" : [
#             {
#                 "\u82f9\u679c" : 0.6666666666666666,
#                 "\u6c34\u679c" : 0.3333333333333333
#             }
#         ],
#         "frozen" : false
#     },
#     "name" : "apples",
#     "weight" : 1.0
# }

# %% [markdown]
# We now add the transition probabilities for our model, which uses our POS bigrams to enumerate what the probabilities are for transiting from one POS tag to another.

# %%
transition_prob_pair={}

for key in tag_bigrams.keys():
    print(key)
    transition_prob_pair[key] = tag_bigrams.get(key)/tags_count[key[0]]
    
    
for tag_state in to_pass_states :
    for next_tag_state in to_pass_states:
        #hmm_model.add_transition(tag_state, next_tag_state,0)
        if (tag_state.name, next_tag_state.name) not in transition_prob_pair:
            transition_prob_pair[(tag_state.name, next_tag_state.name)] = 0
        hmm_model.add_transition(tag_state, next_tag_state, transition_prob_pair[(tag_state.name, next_tag_state.name)])
# Out:
# ('our', 'class')
# ('have', 'a')
# ('very', 'good')
# ('classmate', ',')
# ('she', 'not only')
# ('study', 'is')
# ('first-class', ',')
# ('and', 'in')
# ('is', 'usually')
# ('been', 'Praise')
# ('character', ',')
# ('she', 'is')
# ('xiayu', ',')
# ('a', 'very')
# ('good', 'student')
# (',', 'annual')
# (',', 'she')
# ('also', 'very')
# ('like', 'class')
# ('collective', 'yesterday')
# ('after school', 'time')
# (',', 'student')
# ('hear', 'ring bell')
# (',', 'a lot')
# ('all', 'get out')
# ('suddently', 'stop')
# ('pace', ',')
# ('I', 'along')
# ('hers', 'eye')
# (',', 'see')
# ('class', 'in')
# ('very', 'massly')
# (',', 'ground')
# ('also', 'a load of')
# ('student', 'left')
# ('paper', 'we')
# ('clean', ',')
# ('place', 'table')
# (',', 'wipe')
# ('blackboard', ',')
# ('very', 'busy')
# ('after', 'a while')
# (',', 'finally')
# ('clean', 'finish')
# ('xiayu', 'place')
# ('garbage', 'in')
# ('a', 'bag')
# (',', 'with')
# ('me', 'go out')
# ('class', ',')
# ('close', 'door')
# (',', 'go')
# ('throw', 'garbage')
# ('she', 'because')
# ('run', 'too')
# ('fast', ',')
# ('incaution', 'fell')
# ('I', 'far away')
# ('see', 'she')
# ('face', 'with')
# ('painful', 'expression')
# ('stand', 'up')
# (',', 'knead')
# ('knee', ',')
# ('insist', 'hold')
# ('garbage', 'throw away')
# (',', 'we')
# ('just', 'clean')
# ('thing', 'back')
# ('home', 'this')
# ('is', 'our')
# ('class', 'good')
# ('student', ',')
# ('I', 'also')
# ('from', 'her')
# ('study', ',')
# ('not only', 'want')
# ('well', 'study')
# (',', 'more')
# ('care', 'our')
# ('class', 'collective')
# (',', 'because')
# ('home', 'march')
# ('arrived', ',')
# ('spring', 'girl')
# ('also', 'quietly')
# ('arrive', 'our')
# ('side', ',')
# ('she', 'lightly')
# (',', 'silent')
# ('walking', ',')
# ('whole body', 'exude')
# ('fragrance', ',')
# ('she', 'shyly')
# ('walking', 'one day')
# (',', 'mom')
# ('let', 'me')
# ('go', 'buy')
# ('something', ',')
# ('I', 'happily')
# ('said', 'Okay')
# ('mom', 'I')
# ('know', 'after that')
# ('I', 'just')
# ('go', 'shopping')
# ('I', 'said')
# ('okay', 'uncle')
# ('I', 'eat')
# ('one', 'apple')
# ('I', 'love')
# ('eating', 'pears')
# ('eating', 'apples')
# ('and', 'pears')

# %% [markdown]
# We *bake* our model:

# %%
hmm_model.bake()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-121-7edf17e4acd2> in <module>
# ----> 1 hmm_model.bake()
#
# ~\Anaconda3\lib\site-packages\pomegranate\hmm.pyx in pomegranate.hmm.HiddenMarkovModel.bake()
#
# ~\Anaconda3\lib\site-packages\networkx\classes\reportviews.py in <genexpr>(.0)
#     665     def __iter__(self):
#     666         return (self._report(n, nbr, dd) for n, nbrs in self._nodes_nbrs()
# --> 667                 for nbr, dd in nbrs.items())
#     668
#     669     def __contains__(self, e):
#
# ~\Anaconda3\lib\site-packages\networkx\classes\reportviews.py in <lambda>(n, nbr, dd)
#     653         # Set _report based on data and default
#     654         if data is True:
# --> 655             self._report = lambda n, nbr, dd: (n, nbr, dd)
#     656         elif data is False:
#     657             self._report = lambda n, nbr, dd: (n, nbr)
#
# KeyboardInterrupt:

# %% [markdown]
# We can now evaluate the accuracy of our HMM model and compare it to our BOW model:

# %%
hmm_training_acc = accuracy(data.training_set.X, data.training_set.Y, hmm_model)
print("training accuracy basic hmm model: {:.2f}%".format(100 * hmm_training_acc))

hmm_testing_acc = accuracy(data.testing_set.X, data.testing_set.Y, hmm_model)
print("testing accuracy basic hmm model: {:.2f}%".format(100 * hmm_testing_acc))

# %% [markdown]
# Here's a decoding example:

# %%
for key in data.testing_set.keys[:3]:
    print("Sentence Key: {}\n".format(key))
    #print(type(data.sentences[key]))
    print("Sentence: {}\n".format(data.sentences[key].words))
    print("Predicted labels:\n-----------------")
    #print(data.sentences[key].words)
    print(simplify_decoding(data.sentences[key].words, hmm_model))
    
    print("Actual labels:\n--------------")
    print(data.sentences[key].tags)
    print("\n")

# %% [markdown]
# A 96% accuracy for our HMM model compared to a 93% accuracy for our BOW model is a ***huge*** improvement as it brings language understanding error to below 4%, and 5% error is considered a *gold standard* for NLP. Speech-to-text frameworks like Alexa and Siri only started betting popular when they crossed the 5% threshold.
#
# # References
#
# - Hands on Markov models with python, by Ankur Ankan and Abinash Panda, [on amazon](https://www.amazon.com/Hands-Markov-Models-Python-probabilistic/dp/1788625447/ref=sr_1_2?keywords=hands+on+markov+models+with+python&qid=1581280984&sr=8-2)</div>
#
# - [Universal Dependency Parsing from Scratch](https://nlp.stanford.edu/pubs/qi2018universal.pdf)
#
# - [Statistical Machine Translation](https://en.wikipedia.org/wiki/Statistical_machine_translation)
#
# - [Language Models](https://en.wikipedia.org/wiki/Language_model).
#
# # Homework
#
# Use the methodology in this notebook to build a statistical language translator, *from your language to english*. So, from Hindi or Chinese to English. Teams of **3** students. You *have* to use a Hidden Markov Model and `pomegranate` as your HMM library, to ensure all student teams start from the same baseline. Start from a Most Frequent Word (BOW) translation baseline, then move on to a Hidden Markov Model to improve translation. How much can you improve it by? The translation engine with the best accuracy ***improvement***, per language, will be presented in class.
