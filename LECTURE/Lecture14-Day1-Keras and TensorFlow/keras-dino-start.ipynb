# %% [markdown]
# <div style="text-align: right">INFO 6105 Data Science Eng Methods and Tools, Lecture 14 Day 1</div>
# <div style="text-align: right">Dino Konstantopoulos, 13 April 2020</div>

# %% [markdown]
# # Keras
#
# <br />
# <left>
# <img src="ipynb.images/keras-hellboy.png" width=250 />
# </left>
#
# Minimalist, modular, Open Source Neural Networks API library, written in Python and capable of running on top of either TensorFlow or Theano. Written by [François Chollet](https://fchollet.com/) and adopted by Google's brain team and a number of other frameworks for its simplicity.
#
# - Developed with a focus on going from idea to result with the least possible delay
# - Fast prototyping (modularity, minimalism, extensibility)
# - Supports both convolutional networks and recurrent networks, as well as combinations
# - Supports arbitrary connectivity schemes (including multi-input and multi-output training)
# - Runs seamlessly on CPU and GPU
# - Initially developed as part of the research effort of project ONEIROS (Open-ended Neuro-Electronic Intelligent Robot Operating System)
#
# ### References
# - http://keras.io/
# - http://keras.io/documentation/
# - http://robotfuture.net
# - https://github.com/fchollet/keras
#
# ### Install (already installed if you have tensorflow)
# ```(python)
# pip install keras
# ```

# %%
#pip install keras

# %% [markdown]
# Keras (κέρας) means [horn](https://en.wikipedia.org/wiki/Horn_(anatomy)) in Greek, and it's a play on the greek words κέρας (horn) / κραίνω (fulfill), and ἐλέφας (ivory) / ἐλεφαίρομαι (deceive).
#
# <br />
# <center>
# <img src="ipynb.images/odyssey.jpg" width=400 />
# </center>
#
# Reference to a literary image from ancient Greek literature, first found in the [Odyssey](https://en.wikipedia.org/wiki/Odyssey), where dream spirits (Oneiroi, singular [Oneiros](https://en.wikipedia.org/wiki/Oneiros)) are divided between those who deceive with false visions and arrive to Earth through a gate of ivory ([blue pill](https://en.wikipedia.org/wiki/Red_pill_and_blue_pill) in [the Matrix®](https://en.wikipedia.org/wiki/The_Matrix)), and those who announce a future that will come to pass and arrive through a gate of horn ([red pill](https://en.wikipedia.org/wiki/Red_pill_and_blue_pill) in [the Matrix®](https://en.wikipedia.org/wiki/The_Matrix)).
#
# <br />
# <center>
# <img src="ipynb.images/odyssey3.jpg" width=400 />
# </center>
#
# These spirits reappear in [Harry Potter](https://en.wikipedia.org/wiki/Magical_creatures_in_Harry_Potter).

# %% [markdown]
# ## Homer's Odyssey
#
# <br />
# <center>
# <img src="ipynb.images/odyssey2.jpg" width=400 />
# </center>
#
# >*Oneiroi are beyond our unravelling --who can be sure what tale they tell? Not all that men look for comes to pass. Two gates there are that give passage to fleeting Oneiroi; one is made of horn, one of ivory. The Oneiroi that pass through sawn ivory are deceitful, bearing a message that will not be fulfilled; those that come out through polished horn have truth behind them, to be accomplished for men who see them*.
# - [Homer](https://en.wikipedia.org/wiki/Homer), [Odyssey](https://en.wikipedia.org/wiki/Odyssey) 19 ([Shewring](https://en.wikipedia.org/wiki/English_translations_of_Homer) translation)
#
# The Greek [Odyssey](https://en.wikipedia.org/wiki/Odyssey) (circa 800 BC) is an epic poem alike India's [Bhagavad Gita](https://en.wikipedia.org/wiki/Bhagavad_Gita) or the [Mahabharata](https://en.wikipedia.org/wiki/Mahabharata), a Sanskrit epic narrating the struggle between two groups of cousins, the Kaurava and the Pāṇḍava princes (circa 400 BC), and like China's [Hēi Àn Zhuàn](https://en.wikipedia.org/wiki/Epic_of_Darkness) or 黑暗传, myths relating to the creation of the world from the birth of Pangu, the first living being and the creator of all in some versions of Chinese mythology, written in the [Tang](https://en.wikipedia.org/wiki/Tang_dynasty) Dynasty (600 to 900 AD).

# %% [markdown]
# Keras by [François Chollet](https://www.linkedin.com/in/fchollet) is now the main API of Tensorflow 2.0.
#
# We will use Keras to showcase how neural network build models: Going from ***bunny clouds*** to ***bunny meshes***. For simplicity, we will start with a *single* neuron and 1D data.
#
# # Activation functions recap
#
# Let's start with a recap on activation functions, in 1 and 2D:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import math
# %matplotlib inline
sns.set_style('whitegrid')
sns.set_context('talk')

# %%
def sigmoid(z):
    return 1 / (1 + np.exp(-z))

def relu(z):
    return np.maximum(0, z)

def derivative(f, z, eps=0.000001):
    return (f(z + eps) - f(z - eps))/(2 * eps)

# %%
z = np.linspace(-5, 5, 200)

plt.figure(figsize=(11,4))

plt.subplot(121)
plt.plot(z, np.sign(z), "r-", linewidth=1, label="Step")
plt.plot(z, sigmoid(z), "g--", linewidth=2, label="Sigmoid")
plt.plot(z, np.tanh(z), "b-", linewidth=2, label="Tanh")
plt.plot(z, relu(z), "m-.", linewidth=2, label="ReLU")
plt.grid(True)
plt.legend(loc="center right", fontsize=14)
plt.title("Activation functions", fontsize=14)
plt.axis([-5, 5, -1.2, 1.2])

plt.subplot(122)
plt.plot(z, derivative(np.sign, z), "r-", linewidth=1, label="Step")
plt.plot(0, 0, "ro", markersize=5)
plt.plot(0, 0, "rx", markersize=10)
plt.plot(z, derivative(sigmoid, z), "g--", linewidth=2, label="Sigmoid")
plt.plot(z, derivative(np.tanh, z), "b-", linewidth=2, label="Tanh")
plt.plot(z, derivative(relu, z), "m-.", linewidth=2, label="ReLU")
plt.grid(True)
#plt.legend(loc="center right", fontsize=14)
plt.title("Derivatives", fontsize=14)
plt.axis([-5, 5, -0.2, 1.2])
# Out:
# (-5.0, 5.0, -0.2, 1.2)

# %% [markdown]
# Non-linear activation functions help us build classifiers that are impossible to build with using linear brains like our caterpilar one. This single fact is one of the major factors for the dark ages in AI from the 1960s to the late 1990s.

# %%
def heaviside(z):
    return (z >= 0).astype(z.dtype)

def mlp_xor(x1, x2, activation=heaviside):
    return activation(-activation(x1 + x2 - 1.5) + activation(x1 + x2 - 0.5) - 0.5)

# %%
x1s = np.linspace(-0.2, 1.2, 100)
x2s = np.linspace(-0.2, 1.2, 100)
x1, x2 = np.meshgrid(x1s, x2s)

z1 = mlp_xor(x1, x2, activation=heaviside)
z2 = mlp_xor(x1, x2, activation=sigmoid)

plt.figure(figsize=(10,4))

plt.subplot(121)
plt.contourf(x1, x2, z1)
plt.plot([0, 1], [0, 1], "gs", markersize=20)
plt.plot([0, 1], [1, 0], "y^", markersize=20)
plt.title("Activation function: heaviside", fontsize=14)
plt.grid(True)

plt.subplot(122)
plt.contourf(x1, x2, z2)
plt.plot([0, 1], [0, 1], "gs", markersize=20)
plt.plot([0, 1], [1, 0], "y^", markersize=20)
plt.title("Activation function: sigmoid", fontsize=14)
plt.grid(True)

# %% [markdown]
# # One Neuron
#
# Let's build ourselves a neuron. Let's start with some ridiculously simple data:

# %%
import os
os.environ['KERAS_BACKEND'] = 'theano'
import keras as ks
# Out:
# Using Theano backend.
# WARNING (theano.configdefaults): g++ not available, if using conda: `conda install m2w64-toolchain`
# C:\Users\liaoz\Anaconda3\lib\site-packages\theano\configdefaults.py:560: UserWarning: DeprecationWarning: there is no c++ compiler.This is deprecated and with Theano 0.11 a c++ compiler will be mandatory
#   warnings.warn("DeprecationWarning: there is no c++ compiler."
# WARNING (theano.configdefaults): g++ not detected ! Theano will be unable to execute optimized C-implementations (for both CPU and GPU) and will default to Python implementations. Performance will be severely degraded. To remove this warning, set Theano flags cxx to an empty string.
# WARNING (theano.tensor.blas): Using NumPy C-API based implementation for BLAS functions.

# %%
n_points = 200
x = np.linspace(0, 2, n_points)
y = np.array([0] * int(n_points / 2) + list(x[:int(n_points / 2)])) * 2

plt.figure(figsize=(5, 2))
plt.plot(x, y, linewidth=2)
plt.title('ridiculously simple data')
plt.xlabel('a')
plt.ylabel('b')
# Out:
# Text(0, 0.5, 'b')

# %% [markdown]
# >**NOTE**: The data we're going to model with in this notebook consists of **point-clouds** (`x = np.linspace(0, 2, n_points)`). It is ***not*** continuous, even though it *looks* continuous when we plot it. The model however (the mesh bunny), ***will be*** continuous!
#
# Before **training** a model, you **configure** the learning process with 3 parameters. This is called **compiling** a model. In computer programming, compilation is the translation of **source code** into **object code** by a **compiler**. We also did this with `conx`.
#
# These are the 3 parameters:
# - Optimizer: This could be the string identifier of an existing optimizer (such as rmsprop or adagrad), or an instance of the Optimizer class
# - Loss function: This is the objective that the model will try to minimize. It can be the string identifier of an existing loss function (such as categorical_crossentropy or mse), or it can be an objective function
# - List of metrics: For any classification problem you will want to set this to metrics=['accuracy']

# %%
from keras.models import Sequential
from keras.layers.core import Dense, Activation
import numpy as np
import os

np.random.seed(0)
model = Sequential()
model.add(Dense(output_dim=1, input_dim=1, init="normal"))
model.add(Activation("relu"))
model.compile(loss='mean_squared_error', optimizer='sgd')
# Out:
# C:\Users\liaoz\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(input_dim=1, units=1, kernel_initializer="normal")`

# %%
# print initial weigths
weights = model.layers[0].get_weights()
w0 = weights[0][0][0]
w1 = weights[1][0]
print('neural net initialized with weigths w0: {w0:.2f}, w1: {w1:.2f}'.format(**locals()))
# Out:
# neural net initialized with weigths w0: -0.04, w1: 0.00

# %% [markdown]
# Keras models are trained on NumPy arrays of input **data** and **labels**.
#
# This is an artificial **neuron** with **many** inputs and outputs, and then one with only **one** input and output:
#
# <br />
# <center>
# <img src="ipynb.images/neuron-one-many.png" width=400 />
# </center>
#
# Let's save our training history to ***see*** how Keras trains. Just to pacify Elon Musk who thinks that Neural nets are the work of the [devil](https://www.vox.com/future-perfect/2018/11/2/18053418/elon-musk-artificial-intelligence-google-deepmind-openai).

# %%
from keras.callbacks import Callback

class TrainingHistory(Callback):
    def on_train_begin(self, logs={}):
        self.losses = []
        self.predictions = []
        self.i = 0
        self.save_every = 50

    def on_batch_end(self, batch, logs={}):
        self.losses.append(logs.get('loss'))
        self.i += 1        
        if self.i % self.save_every == 0:        
            pred = model.predict(X_train)
            self.predictions.append(pred)
            
history = TrainingHistory()

# %% [markdown]
# The training API is reminiscent of `sklearn`'s training API. Let's train our **single** neuron on our ***ridiculously simple data*** that we created above.

# %%
X_train = np.array(x, ndmin=2).T
Y_train = np.array(y, ndmin=2).T
model.fit(X_train,
          Y_train,
          nb_epoch=2000,
          verbose=0,
          callbacks=[history])

# print trained weights
weights = model.layers[0].get_weights()
w0 = weights[0][0][0]
w1 = weights[1][0]
print('neural net weigths after training w0: {w0:.2f}, w1: {w1:.2f}'.format(**locals()))
# Out:
# C:\Users\liaoz\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
#   import sys
# neural net weigths after training w0: -0.04, w1: 0.00

# %% [markdown]
# ### Prerequisites
#
# To build animations:
# - Download ffmpeg (install at C:\ffmpeg)
#
# >For Windows: https://ffmpeg.zeranoe.com/builds/
# Directions: http://www.wikihow.com/Install-FFmpeg-on-Windows
#
# >For OSX: http://www.renevolution.com/ffmpeg/2013/03/16/how-to-install-ffmpeg-on-mac-os-x.html
#
# To reset your PATH environment variable without killing and restarting your command console:
# ```(python)
# SET PATH=%PATH%;C:\ffmpeg\bin
# ```
#
# But you want to add `ffmpeg\bin` in your PATH. It's good juju.
#
# ***Also***, create subfolders `videos` and `images` in your `C:\Users\<username>` folder
#
# >**Pit Stop**: This will take 5 minutes, so let's take a pit stop and park our F1 for gas and a change of tires. Meet back in 10 minutes.

# %% [markdown]
# Let's plot the ***animation*** of our training process, which is also called **auto-encoding** (a generative model):

# %%
# save the animation
import matplotlib.animation as animation

fig = plt.figure(figsize=(5, 2.5))
plt.plot(x, y,  label='data')
line, = plt.plot(x, history.predictions[0],  label='prediction')
plt.legend(loc='upper left')

def update_line(num):
    plt.title('iteration: {0}'.format((history.save_every * (num + 1))))
    line.set_xdata(x)
    line.set_ydata(history.predictions[num])
    return []

ani = animation.FuncAnimation(fig, update_line, len(history.predictions),
                                   interval=50, blit=True)
ani.save('keras_videos/neuron.mp4', fps=30, extra_args=['-vcodec', 'libx264', '-pix_fmt','yuv420p'])
# Out:
# MovieWriter ffmpeg unavailable; trying to use <class 'matplotlib.animation.PillowWriter'> instead.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\PIL\Image.py in save(self, fp, format, **params)
#    2063             try:
# -> 2064                 format = EXTENSION[ext]
#    2065             except KeyError:
#
# KeyError: '.mp4'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-58a221f0ddf2> in <module>
#      15 ani = animation.FuncAnimation(fig, update_line, len(history.predictions),
#      16                                    interval=50, blit=True)
# ---> 17 ani.save('keras_videos/neuron.mp4', fps=30, extra_args=['-vcodec', 'libx264', '-pix_fmt','yuv420p'])
#
# ~\Anaconda3\lib\site-packages\matplotlib\animation.py in save(self, filename, writer, fps, dpi, codec, bitrate, extra_args, metadata, extra_anim, savefig_kwargs, progress_callback)
#    1154                             progress_callback(frame_number, total_frames)
#    1155                             frame_number += 1
# -> 1156                     writer.grab_frame(**savefig_kwargs)
#    1157
#    1158         # Reconnect signal for first draw if necessary
#
# ~\Anaconda3\lib\contextlib.py in __exit__(self, type, value, traceback)
#     117         if type is None:
#     118             try:
# --> 119                 next(self.gen)
#     120             except StopIteration:
#     121                 return False
#
# ~\Anaconda3\lib\site-packages\matplotlib\animation.py in saving(self, fig, outfile, dpi, *args, **kwargs)
#     230             yield self
#     231         finally:
# --> 232             self.finish()
#     233
#     234
#
# ~\Anaconda3\lib\site-packages\matplotlib\animation.py in finish(self)
#     575         self._frames[0].save(
#     576             self._outfile, save_all=True, append_images=self._frames[1:],
# --> 577             duration=int(1000 / self.fps), loop=0)
#     578
#     579
#
# ~\Anaconda3\lib\site-packages\PIL\Image.py in save(self, fp, format, **params)
#    2064                 format = EXTENSION[ext]
#    2065             except KeyError:
# -> 2066                 raise ValueError("unknown file extension: {}".format(ext))
#    2067
#    2068         if format.upper() not in SAVE:
#
# ValueError: unknown file extension: .mp4

# %% [markdown]
# uh-oh..
#
# gulp (hard swallow)...
#
# <br />
# <center>
# <img src="ipynb.images/oopsie.gif" width=400 />
# </center>

# %% [markdown]
# Does our bunny mesh match our bunny cloud?

# %%
plt.figure(figsize=(5, 2.5))
plt.plot(x, y, label='data')
plt.plot(x, history.predictions[0], label='prediction')
plt.legend(loc='upper left')
plt.title('iteration: 0')
plt.savefig('images/neuron_start.png')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-17-a1261be4f42a> in <module>
#       4 plt.legend(loc='upper left')
#       5 plt.title('iteration: 0')
# ----> 6 plt.savefig('images/neuron_start.png')
#
# ~\Anaconda3\lib\site-packages\matplotlib\pyplot.py in savefig(*args, **kwargs)
#     720 def savefig(*args, **kwargs):
#     721     fig = gcf()
# --> 722     res = fig.savefig(*args, **kwargs)
#     723     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     724     return res
#
# ~\Anaconda3\lib\site-packages\matplotlib\figure.py in savefig(self, fname, transparent, **kwargs)
#    2178             self.patch.set_visible(frameon)
#    2179
# -> 2180         self.canvas.print_figure(fname, **kwargs)
#    2181
#    2182         if frameon:
#
# ~\Anaconda3\lib\site-packages\matplotlib\backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, **kwargs)
#    2080                     orientation=orientation,
#    2081                     bbox_inches_restore=_bbox_inches_restore,
# -> 2082                     **kwargs)
#    2083             finally:
#    2084                 if bbox_inches and restore_bbox:
#
# ~\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args, **kwargs)
#     528             renderer = self.get_renderer()
#     529             with cbook._setattr_cm(renderer, dpi=self.figure.dpi), \
# --> 530                     cbook.open_file_cm(filename_or_obj, "wb") as fh:
#     531                 _png.write_png(renderer._renderer, fh,
#     532                                self.figure.dpi, metadata=metadata)
#
# ~\Anaconda3\lib\contextlib.py in __enter__(self)
#     110         del self.args, self.kwds, self.func
#     111         try:
# --> 112             return next(self.gen)
#     113         except StopIteration:
#     114             raise RuntimeError("generator didn't yield") from None
#
# ~\Anaconda3\lib\site-packages\matplotlib\cbook\__init__.py in open_file_cm(path_or_file, mode, encoding)
#     445 def open_file_cm(path_or_file, mode="r", encoding=None):
#     446     r"""Pass through file objects and context-manage `.PathLike`\s."""
# --> 447     fh, opened = to_filehandle(path_or_file, mode, True, encoding)
#     448     if opened:
#     449         with fh:
#
# ~\Anaconda3\lib\site-packages\matplotlib\cbook\__init__.py in to_filehandle(fname, flag, return_opened, encoding)
#     430             fh = bz2.BZ2File(fname, flag)
#     431         else:
# --> 432             fh = open(fname, flag, encoding=encoding)
#     433         opened = True
#     434     elif hasattr(fname, 'seek'):
#
# FileNotFoundError: [Errno 2] No such file or directory: 'images/neuron_start.png'

# %% [markdown]
# Not really..
#
# What's our **training error**?

# %%
plt.figure(figsize=(6, 3))
plt.plot(history.losses)
plt.ylabel('error')
plt.xlabel('iteration')
plt.title('training error')
# Out:
# Text(0.5, 1.0, 'training error')

# %% [markdown]
# Hmm... Not good! We're ***not*** learning!
#
# Do you remember how I mentioned [vanishing gradients](https://en.wikipedia.org/wiki/Vanishing_gradient_problem) during our discussion on activation functions? This is exactly *what's happening here*!
#
#
# <br />
# <center>
# <img src="ipynb.images/bad-robot.jpg" width=400 />
# </center>

# %%
print('neural net weigths after training w0: {w0:.2f}, w1: {w1:.2f}'.format(**locals()))
# Out:
# neural net weigths after training w0: -0.04, w1: 0.00

# %% [markdown]
# *No* change in weights!
#
# ### Back to the drawing board: Modify model hyperparameters
#
# Let's use batch normalization, also called [mini-batch](https://en.wikipedia.org/wiki/Batch_normalization), a technique for improving speed, performance, and stability of artificial neural networks, introduced in 2015 paper.It normalizes the input layer by adjusting and scaling activations., thereyby smoothing the objective function to improve performance.
#
# In Keras, it's the `batch-size` parameter:

# %%
# Part 6: larger batch size
history = TrainingHistory()
model = Sequential()
model.add(Dense(output_dim=1, input_dim=1, init="normal"))
model.add(Activation("relu"))
model.compile(loss='mean_squared_error', optimizer='sgd')
model.fit(X_train,
          Y_train,
          batch_size=200,
          nb_epoch=2000,
          verbose=0,
          callbacks=[history])

plt.figure(figsize=(6, 3))
plt.plot(history.losses)
plt.ylabel('error')
plt.xlabel('iteration')
plt.title('training error')
# Out:
# C:\Users\liaoz\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(input_dim=1, units=1, kernel_initializer="normal")`
#   after removing the cwd from sys.path.
# C:\Users\liaoz\Anaconda3\lib\site-packages\ipykernel_launcher.py:12: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
#   if sys.path[0] == '':
# Text(0.5, 1.0, 'training error')

# %% [markdown]
# 哇！ Now look at that training error going to zero!
#
# <br />
# <center>
# <img src="ipynb.images/good-robot.jpg" width=200 />
# </center>
#
# And if we plot results:

# %%
# !pwd
# Out:
# 'pwd' 不是内部或外部命令，也不是可运行的程序
# 或批处理文件。

# %%
fig = plt.figure(figsize=(5, 2.5))
plt.plot(x, y,  label='data')
line, = plt.plot(x, history.predictions[0],  label='prediction')
plt.legend(loc='upper left')

ani = animation.FuncAnimation(fig, update_line, len(history.predictions),
                                   interval=50, blit=True)
ani.save('keras_videos/neuron-large_batch.mp4', fps=30, extra_args=['-vcodec', 'libx264', '-pix_fmt','yuv420p'])
# Out:
# MovieWriter ffmpeg unavailable; trying to use <class 'matplotlib.animation.PillowWriter'> instead.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\PIL\Image.py in save(self, fp, format, **params)
#    2063             try:
# -> 2064                 format = EXTENSION[ext]
#    2065             except KeyError:
#
# KeyError: '.mp4'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-49fb2a45ef30> in <module>
#       6 ani = animation.FuncAnimation(fig, update_line, len(history.predictions),
#       7                                    interval=50, blit=True)
# ----> 8 ani.save('keras_videos/neuron-large_batch.mp4', fps=30, extra_args=['-vcodec', 'libx264', '-pix_fmt','yuv420p'])
#
# ~\Anaconda3\lib\site-packages\matplotlib\animation.py in save(self, filename, writer, fps, dpi, codec, bitrate, extra_args, metadata, extra_anim, savefig_kwargs, progress_callback)
#    1154                             progress_callback(frame_number, total_frames)
#    1155                             frame_number += 1
# -> 1156                     writer.grab_frame(**savefig_kwargs)
#    1157
#    1158         # Reconnect signal for first draw if necessary
#
# ~\Anaconda3\lib\contextlib.py in __exit__(self, type, value, traceback)
#     117         if type is None:
#     118             try:
# --> 119                 next(self.gen)
#     120             except StopIteration:
#     121                 return False
#
# ~\Anaconda3\lib\site-packages\matplotlib\animation.py in saving(self, fig, outfile, dpi, *args, **kwargs)
#     230             yield self
#     231         finally:
# --> 232             self.finish()
#     233
#     234
#
# ~\Anaconda3\lib\site-packages\matplotlib\animation.py in finish(self)
#     575         self._frames[0].save(
#     576             self._outfile, save_all=True, append_images=self._frames[1:],
# --> 577             duration=int(1000 / self.fps), loop=0)
#     578
#     579
#
# ~\Anaconda3\lib\site-packages\PIL\Image.py in save(self, fp, format, **params)
#    2064                 format = EXTENSION[ext]
#    2065             except KeyError:
# -> 2066                 raise ValueError("unknown file extension: {}".format(ext))
#    2067
#    2068         if format.upper() not in SAVE:
#
# ValueError: unknown file extension: .mp4

# %% [markdown]
# ### What is we start with zero weights?
#
# Let's give training another shot, initializing our weights to zero:

# %%
# Part 7: Dying ReLu problem

np.random.seed(2)
history = TrainingHistory()
model = Sequential()
model.add(Dense(output_dim=1, input_dim=1, init="normal"))
model.add(Activation("relu"))
model.compile(loss='mean_squared_error', optimizer='sgd')

weights = model.layers[0].get_weights()
w0 = weights[0][0][0]
w1 = weights[1][0]
print('neural net initialized with weigths w0: {w0:.2f}, w1: {w1:.2f}'.format(**locals()))
# Out:
# C:\Users\liaoz\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(input_dim=1, units=1, kernel_initializer="normal")`
# neural net initialized with weigths w0: 0.04, w1: 0.00

# %% [markdown]
# What if we do this:

# %%
weights[0][0][0] = 0.

# %% [markdown]
# Let's train again:

# %%
model.fit(X_train,
          Y_train,
          batch_size=200,
          nb_epoch=2000,
          verbose=0,
          callbacks=[history])

weights = model.layers[0].get_weights()
w0 = weights[0][0][0]
w1 = weights[1][0]
print('neural net weigths after training w0: {w0:.2f}, w1: {w1:.2f}'.format(**locals()))
print('dying ReLU problem!')
print('http://datascience.stackexchange.com/questions/5706/what-is-the-dying-relu-problem-in-neural-networks')

fig = plt.figure(figsize=(5, 2.5))
plt.plot(x, y,  label='data')
line, = plt.plot(x, history.predictions[0],  label='prediction')
plt.xlabel('a')
plt.ylabel('b')
plt.legend(loc='upper left')
# Out:
# C:\Users\liaoz\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
# neural net weigths after training w0: 1.41, w1: -1.12
# dying ReLU problem!
# http://datascience.stackexchange.com/questions/5706/what-is-the-dying-relu-problem-in-neural-networks

# %% [markdown]
# Oh-oh! And we did use mini-batch! This is called the [dying ReLu](https://arxiv.org/abs/1903.06733) problem. Read the [URL](http://datascience.stackexchange.com/questions/5706/what-is-the-dying-relu-problem-in-neural-networks) below!

# %%
print('dying ReLU problem!')
print('http://datascience.stackexchange.com/questions/5706/what-is-the-dying-relu-problem-in-neural-networks')
# Out:
# dying ReLU problem!
# http://datascience.stackexchange.com/questions/5706/what-is-the-dying-relu-problem-in-neural-networks

# %%
plt.figure(figsize=(5, 2.5))
plt.plot(history.losses)
plt.ylabel('error')
plt.xlabel('iteration')
plt.title('training error')
# Out:
# Text(0.5, 1.0, 'training error')

# %% [markdown]
# Pretty strange indeed! Looks like we won at step 0. But not really..
#
# This problem is usually fixed using a ***leaky ReLU***, which we mentioned during our discussion on activation functions. Let's move on to more neurons now.

# %% [markdown]
# # Sixty neurons
#
# <br />
# <center>
# <img src="ipynb.images/brain.gif" width=200 />
# </center>
#
# Let's try increasing our level of intelligence by augmenting our brain from ***one*** to ***sixty*** neurons (still only ***one*** layer).
#
# <br />
# <center>
# <img src="ipynb.images/neurons-60.png" width=600 />
# </center>
#
# Let's work with slightly more complicated data: Let's model a *noisy* **double-sine** function.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import math

sns.set_style('whitegrid')
sns.set_context('talk')

np.random.seed(0)
x = np.linspace(0, 2 * math.pi, 200)
sine = np.sin(x)
err = np.random.normal(0, 0.2, len(sine))
y = sine + err
plt.figure(figsize=(5, 3))
plt.plot(x, y)
plt.xlim([0, 2 * math.pi])
plt.title('A noisy sine')
# Out:
# Text(0.5, 1.0, 'A noisy sine')

# %% [markdown]
# Let's **compile** a Keras model with a single layer of 60 neurons. This should remind you of our caterpilar brain, slightly larger, with non-linear activation.

# %%
from keras.models import Sequential
from keras.layers.core import Dense, Activation

n_conn = 60
model = Sequential()
model.add(Dense(output_dim=n_conn, input_dim=1))
model.add(Activation("relu"))
model.add(Dense(output_dim=1))
model.compile(loss='mean_squared_error', optimizer='sgd')
# Out:
# C:\Users\liaoz\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(input_dim=1, units=60)`
#
# C:\Users\liaoz\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(units=1)`

# %% [markdown]
# Let's save the training history.

# %%
from keras.callbacks import Callback

class TrainingHistory(Callback):
    def on_train_begin(self, logs={}):
        self.losses = []
        self.predictions = []
        self.i = 0
        self.save_every = 50

    def on_batch_end(self, batch, logs={}):
        self.losses.append(logs.get('loss'))
        self.i += 1        
        if self.i % self.save_every == 0:        
            pred = model.predict(X_train)
            self.predictions.append(pred)
            
X_train = np.array(x, ndmin=2).T
Y_train = np.array(y, ndmin=2).T

# %% [markdown]
# Let's **train** our model in 5000 timesteps:

# %%
history = TrainingHistory()
res = model.fit(X_train,
          Y_train,
          nb_epoch=5000,
          verbose=0,
          callbacks=[history])
# Out:
# C:\Users\liaoz\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
#
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.216421). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.108211). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.198489). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.105986). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.193595). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.108015). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.192466). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.222836). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.111418). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.194499). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.183008). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.189514). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.100731). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.244345). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.122173). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.179352). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.194064). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.170524). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.182872). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.211422). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.105711). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.203307). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.101654). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.188467). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.185514). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.187217). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.171546). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.200365). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.100183). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.180538). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.100347). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.188491). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.101738). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.156561). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.184781). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.171833). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.180572). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.174513). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.177507). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.172733). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.157791). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.170563). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.176932). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.189922). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.172848). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.164560). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.175062). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.173973). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.106120). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.214988). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.107494). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.173593). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.217389). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.108695). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.177396). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.172539). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.175875). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.175977). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.101910). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.152599). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.153270). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.173534). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.154586). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.153324). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.191286). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.151930). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.154267). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.155111). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.164606). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.149795). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.201461). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.100730). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.205987). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.102993). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.158988). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.166831). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.154127). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.193483). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.175551). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.176508). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.198783). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.184050). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.162837). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.157579). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.154212). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.176528). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.182544). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.156755). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.151595). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.184756). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.155602). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.153125). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.157048). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.170543). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.176531). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.184504). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.179088). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.170525). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.185485). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.205470). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.102735). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.170798). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.183405). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.176507). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.192001). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.153342). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.169282). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.190489). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.201480). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.100740). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.210246). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.105123). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.209513). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.104757). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.156181). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.153608). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.167387). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.156257). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.154843). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.154037). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.161865). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)

# %% [markdown]
# Let's animate our learning process:

# %%
import matplotlib.animation as animation

def visualize_training(history, name):
    fig = plt.figure(figsize=(5, 2.5))
    plt.plot(x, y, label='data')
    line, = plt.plot(x, history.predictions[0],  label='prediction')
    plt.legend()

    def update_line(num):
        plt.title('iteration: {0}'.format((history.save_every * (num + 1))))
        line.set_xdata(x)
        line.set_ydata(history.predictions[num])
        return []

    ani = animation.FuncAnimation(fig, update_line, len(history.predictions),
                                       interval=50, blit=True)
    ani.save('keras_videos/{0}.mp4'.format(name), dpi=100, extra_args=['-vcodec', 'libx264', '-pix_fmt','yuv420p'])

# %%
visualize_training(history, 'noisy-sine-one-layer')
# Out:
# MovieWriter ffmpeg unavailable; trying to use <class 'matplotlib.animation.PillowWriter'> instead.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\PIL\Image.py in save(self, fp, format, **params)
#    2063             try:
# -> 2064                 format = EXTENSION[ext]
#    2065             except KeyError:
#
# KeyError: '.mp4'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-33-d10c776bf63a> in <module>
# ----> 1 visualize_training(history, 'noisy-sine-one-layer')
#
# <ipython-input-32-6167b7944d07> in visualize_training(history, name)
#      15     ani = animation.FuncAnimation(fig, update_line, len(history.predictions),
#      16                                        interval=50, blit=True)
# ---> 17     ani.save('keras_videos/{0}.mp4'.format(name), dpi=100, extra_args=['-vcodec', 'libx264', '-pix_fmt','yuv420p'])
#
# ~\Anaconda3\lib\site-packages\matplotlib\animation.py in save(self, filename, writer, fps, dpi, codec, bitrate, extra_args, metadata, extra_anim, savefig_kwargs, progress_callback)
#    1154                             progress_callback(frame_number, total_frames)
#    1155                             frame_number += 1
# -> 1156                     writer.grab_frame(**savefig_kwargs)
#    1157
#    1158         # Reconnect signal for first draw if necessary
#
# ~\Anaconda3\lib\contextlib.py in __exit__(self, type, value, traceback)
#     117         if type is None:
#     118             try:
# --> 119                 next(self.gen)
#     120             except StopIteration:
#     121                 return False
#
# ~\Anaconda3\lib\site-packages\matplotlib\animation.py in saving(self, fig, outfile, dpi, *args, **kwargs)
#     230             yield self
#     231         finally:
# --> 232             self.finish()
#     233
#     234
#
# ~\Anaconda3\lib\site-packages\matplotlib\animation.py in finish(self)
#     575         self._frames[0].save(
#     576             self._outfile, save_all=True, append_images=self._frames[1:],
# --> 577             duration=int(1000 / self.fps), loop=0)
#     578
#     579
#
# ~\Anaconda3\lib\site-packages\PIL\Image.py in save(self, fp, format, **params)
#    2064                 format = EXTENSION[ext]
#    2065             except KeyError:
# -> 2066                 raise ValueError("unknown file extension: {}".format(ext))
#    2067
#    2068         if format.upper() not in SAVE:
#
# ValueError: unknown file extension: .mp4

# %% [markdown]
# Oh... We were able to model the first "*kink*" in our 1D mesh cloud, but ***not the second***!
#
# >**DISCUSSION**: Why do you think?
#
# This is what we started with at step 0:

# %%
    plt.figure(figsize=(5, 2.5))
    plt.plot(x, y, label='data')
    plt.plot(x, history.predictions[0], label='prediction')
    plt.legend()
    plt.title('iteration: 0')
    plt.savefig('images/{0}.png'.format('noisy-sine-one-layer'))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-34-4c859f1b3624> in <module>
#       4 plt.legend()
#       5 plt.title('iteration: 0')
# ----> 6 plt.savefig('images/{0}.png'.format('noisy-sine-one-layer'))
#
# ~\Anaconda3\lib\site-packages\matplotlib\pyplot.py in savefig(*args, **kwargs)
#     720 def savefig(*args, **kwargs):
#     721     fig = gcf()
# --> 722     res = fig.savefig(*args, **kwargs)
#     723     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     724     return res
#
# ~\Anaconda3\lib\site-packages\matplotlib\figure.py in savefig(self, fname, transparent, **kwargs)
#    2178             self.patch.set_visible(frameon)
#    2179
# -> 2180         self.canvas.print_figure(fname, **kwargs)
#    2181
#    2182         if frameon:
#
# ~\Anaconda3\lib\site-packages\matplotlib\backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, **kwargs)
#    2080                     orientation=orientation,
#    2081                     bbox_inches_restore=_bbox_inches_restore,
# -> 2082                     **kwargs)
#    2083             finally:
#    2084                 if bbox_inches and restore_bbox:
#
# ~\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args, **kwargs)
#     528             renderer = self.get_renderer()
#     529             with cbook._setattr_cm(renderer, dpi=self.figure.dpi), \
# --> 530                     cbook.open_file_cm(filename_or_obj, "wb") as fh:
#     531                 _png.write_png(renderer._renderer, fh,
#     532                                self.figure.dpi, metadata=metadata)
#
# ~\Anaconda3\lib\contextlib.py in __enter__(self)
#     110         del self.args, self.kwds, self.func
#     111         try:
# --> 112             return next(self.gen)
#     113         except StopIteration:
#     114             raise RuntimeError("generator didn't yield") from None
#
# ~\Anaconda3\lib\site-packages\matplotlib\cbook\__init__.py in open_file_cm(path_or_file, mode, encoding)
#     445 def open_file_cm(path_or_file, mode="r", encoding=None):
#     446     r"""Pass through file objects and context-manage `.PathLike`\s."""
# --> 447     fh, opened = to_filehandle(path_or_file, mode, True, encoding)
#     448     if opened:
#     449         with fh:
#
# ~\Anaconda3\lib\site-packages\matplotlib\cbook\__init__.py in to_filehandle(fname, flag, return_opened, encoding)
#     430             fh = bz2.BZ2File(fname, flag)
#     431         else:
# --> 432             fh = open(fname, flag, encoding=encoding)
#     433         opened = True
#     434     elif hasattr(fname, 'seek'):
#
# FileNotFoundError: [Errno 2] No such file or directory: 'images/noisy-sine-one-layer.png'

# %% [markdown]
# This is our training error:

# %%
    plt.figure(figsize=(6, 3))
    plt.plot(history.losses)
    plt.ylabel('error')
    plt.xlabel('iteration')
    plt.ylim([0, 0.5])
    plt.title('training error')
# Out:
# Text(0.5, 1.0, 'training error')

# %% [markdown]
# ### A Better model?
#
# >**Challenge**: Can you come up with a better neural architecture that retains the same "*brainpower*", i.e. number of neurons (60 neurons) and weights, but *increases* modeling intelligence, Dr. Frankenstein?
#
# <br />
# <center>
# <img src="ipynb.images/give-you-life.gif" width=400 />
# </center>

# %% [markdown]
# <details>
#       <summary>Can you come up with this "*clever-er*" architecture?</summary>
# <br />
# <center>
# <img src="ipynb.images/neurons-10-10.png" width=200 />
#     Count the number of weights and compare to the 60 neuron single layer!
# </center>
# </details>
#
# Let's compile:

# %%
n_conn = 10
model = Sequential()
model.add(Dense(output_dim=n_conn, input_dim=1))
model.add(Activation("relu"))
model.add(Dense(output_dim=n_conn))
model.add(Activation("relu"))
model.add(Dense(output_dim=1))
model.compile(loss='mean_squared_error', optimizer='sgd')


n_conn = 60
model = Sequential()
model.add(Dense(output_dim=n_conn, input_dim=1))
model.add(Activation("relu"))
model.add(Dense(output_dim=1))
adam = Adam()
model.compile(loss='mean_squared_error', optimizer=adam)
# Out:
# C:\Users\liaoz\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(input_dim=1, units=10)`
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\liaoz\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(units=10)`
#   """
# C:\Users\liaoz\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(units=1)`
#   import sys

# %% [markdown]
# Let's train:

# %%
X_train = np.array(x, ndmin=2).T
Y_train = np.array(y, ndmin=2).T
history = TrainingHistory()
model.fit(X_train,
          Y_train,
          nb_epoch=5000,
          verbose=0,
          callbacks=[history])
# Out:
# C:\Users\liaoz\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-37-78974b108030> in <module>
#       6           nb_epoch=5000,
#       7           verbose=0,
# ----> 8           callbacks=[history])
#
# ~\Anaconda3\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#    1237                                         steps_per_epoch=steps_per_epoch,
#    1238                                         validation_steps=validation_steps,
# -> 1239                                         validation_freq=validation_freq)
#    1240
#    1241     def evaluate(self,
#
# ~\Anaconda3\lib\site-packages\keras\engine\training_arrays.py in fit_loop(model, fit_function, fit_inputs, out_labels, batch_size, epochs, verbose, callbacks, val_function, val_inputs, shuffle, initial_epoch, steps_per_epoch, validation_steps, validation_freq)
#     194                     ins_batch[i] = ins_batch[i].toarray()
#     195
# --> 196                 outs = fit_function(ins_batch)
#     197                 outs = to_list(outs)
#     198                 for l, o in zip(out_labels, outs):
#
# ~\Anaconda3\lib\site-packages\keras\backend\theano_backend.py in __call__(self, inputs)
#    1428     def __call__(self, inputs):
#    1429         assert isinstance(inputs, (list, tuple))
# -> 1430         outputs = self.function(*inputs)
#    1431         if self._metrics:
#    1432             metrics = self._metrics_function()
#
# ~\Anaconda3\lib\site-packages\theano\compile\function_module.py in __call__(self, *args, **kwargs)
#     901         try:
#     902             outputs =\
# --> 903                 self.fn() if output_subset is None else\
#     904                 self.fn(output_subset=output_subset)
#     905         except Exception:
#
# ~\Anaconda3\lib\site-packages\theano\gof\vm.py in __call__(self)
#     299                 for thunk, node, old_storage in zip(self.thunks, self.nodes,
#     300                                                     self.post_thunk_clear):
# --> 301                     thunk()
#     302                     for old_s in old_storage:
#     303                         old_s[0] = None
#
# ~\Anaconda3\lib\site-packages\theano\gof\op.py in rval(p, i, o, n, params)
#     899             def rval(p=p, i=node_input_storage, o=node_output_storage, n=node,
#     900                      params=params_val):
# --> 901                 r = p(n, [x[0] for x in i], o, params)
#     902                 for o in node.outputs:
#     903                     compute_map[o][0] = True
#
# ~\Anaconda3\lib\site-packages\theano\tensor\blas.py in perform(self, node, inp, out, params)
#     917                     z[:] = -np.dot(x, y)
#     918                 else:
# --> 919                     z[:] = a * np.dot(x, y)
#     920             elif b == 1.0:
#     921                 if a == 1.0:
#
# KeyboardInterrupt:

# %% [markdown]
# Let's visualize our learning:

# %%
visualize_training(history, 'tiny-sine-two-layer')

# %% [markdown]
# >哇！他真棒！
#
# Is adding a second layer the only possible way to increase our learning power? No, we can also watch an episode of GoT... Kidding! We can also use  optimizers such as [Adam](https://towardsdatascience.com/adam-latest-trends-in-deep-learning-optimization-6be9a291375c). Let's ***go back*** to our single layer of 60 neurons and leverage Adam!

# %%
from keras.optimizers import Adam

n_conn = 60
model = Sequential()
model.add(Dense(output_dim=n_conn, input_dim=1))
model.add(Activation("relu"))
model.add(Dense(output_dim=1))
adam = Adam()
model.compile(loss='mean_squared_error', optimizer=adam)
# Out:
# C:\Users\liaoz\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(input_dim=1, units=60)`
#   """
# C:\Users\liaoz\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(units=1)`
#   import sys

# %%
X_train = np.array(x, ndmin=2).T
Y_train = np.array(y, ndmin=2).T
history = TrainingHistory()
model.fit(X_train,
          Y_train,
          nb_epoch=5000,
          verbose=0,
          callbacks=[history])
# Out:
# C:\Users\liaoz\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
#
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.169544). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.211413). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.105707). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.153805). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.150131). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.152600). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.154587). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.152659). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.175482). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.198469). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.145611). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.150597). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.155563). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.150617). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.156581). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.153589). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.146609). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.147606). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.161587). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.149601). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.146608). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.150598). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.160590). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.159593). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.151575). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.148602). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.151616). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.148605). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.152594). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.149599). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.162565). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.145610). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.151595). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.148604). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.165551). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.148603). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.160549). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.147605). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.149600). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.148607). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.148582). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.167553). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.152593). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.152592). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.151594). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.151572). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.152591). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.171541). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.153587). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.184505). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.157556). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.150578). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.150616). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.153585). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.151615). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.151593). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.148623). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.151576). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.149602). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.148615). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.168548). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.150599). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.147625). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.151590). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.160569). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.146607). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.150601). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Users\liaoz\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.146610). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)

# %%
visualize_training(history, 'tiny-sine-one-layer-adam')
# Out:
# MovieWriter ffmpeg unavailable; trying to use <class 'matplotlib.animation.PillowWriter'> instead.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\PIL\Image.py in save(self, fp, format, **params)
#    2063             try:
# -> 2064                 format = EXTENSION[ext]
#    2065             except KeyError:
#
# KeyError: '.mp4'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-40-9ec1f3ce370e> in <module>
# ----> 1 visualize_training(history, 'tiny-sine-one-layer-adam')
#
# <ipython-input-32-6167b7944d07> in visualize_training(history, name)
#      15     ani = animation.FuncAnimation(fig, update_line, len(history.predictions),
#      16                                        interval=50, blit=True)
# ---> 17     ani.save('keras_videos/{0}.mp4'.format(name), dpi=100, extra_args=['-vcodec', 'libx264', '-pix_fmt','yuv420p'])
#
# ~\Anaconda3\lib\site-packages\matplotlib\animation.py in save(self, filename, writer, fps, dpi, codec, bitrate, extra_args, metadata, extra_anim, savefig_kwargs, progress_callback)
#    1154                             progress_callback(frame_number, total_frames)
#    1155                             frame_number += 1
# -> 1156                     writer.grab_frame(**savefig_kwargs)
#    1157
#    1158         # Reconnect signal for first draw if necessary
#
# ~\Anaconda3\lib\contextlib.py in __exit__(self, type, value, traceback)
#     117         if type is None:
#     118             try:
# --> 119                 next(self.gen)
#     120             except StopIteration:
#     121                 return False
#
# ~\Anaconda3\lib\site-packages\matplotlib\animation.py in saving(self, fig, outfile, dpi, *args, **kwargs)
#     230             yield self
#     231         finally:
# --> 232             self.finish()
#     233
#     234
#
# ~\Anaconda3\lib\site-packages\matplotlib\animation.py in finish(self)
#     575         self._frames[0].save(
#     576             self._outfile, save_all=True, append_images=self._frames[1:],
# --> 577             duration=int(1000 / self.fps), loop=0)
#     578
#     579
#
# ~\Anaconda3\lib\site-packages\PIL\Image.py in save(self, fp, format, **params)
#    2064                 format = EXTENSION[ext]
#    2065             except KeyError:
# -> 2066                 raise ValueError("unknown file extension: {}".format(ext))
#    2067
#    2068         if format.upper() not in SAVE:
#
# ValueError: unknown file extension: .mp4

# %% [markdown]
# Wow! It ***worked***， with a *single* layer!
#
# And what if we combine our two-layer model ***and*** use Adam?

# %%
# Part 8
n_conn = 10
model = Sequential()
model.add(Dense(output_dim=n_conn, input_dim=1))
model.add(Activation("relu"))
model.add(Dense(output_dim=n_conn))
model.add(Activation("relu"))
model.add(Dense(output_dim=1))
adam = Adam()
model.compile(loss='mean_squared_error', optimizer=adam)

# %%
X_train = np.array(x, ndmin=2).T
Y_train = np.array(y, ndmin=2).T
history = TrainingHistory()
model.fit(X_train,
          Y_train,
          nb_epoch=5000,
          verbose=0,
          callbacks=[history])

# %%
visualize_training(history, 'tiny-sine-two-layer-adam')

# %% [markdown]
# >**NOTE** Professor, so many hyperparameters to play with! Yup, just like with Bayesian modeling, modeling is an ***art*** *and* a science1

# %% [markdown]
# # Tensorflow
#
# Now that we know our Keras API and how to build ANNs, let's apply this knowledge to Tensorflow, which uses the `tf.keras` API, see [this guide](https://www.tensorflow.org/guide/keras).

# %% [markdown]
# Let's use it ti predict house prices in Boston.

# %% [markdown]
# In a *regression* problem, we aim to predict the output of a continuous value, like a price or a probability. In a *classification* problem (discriminative model), we aim to predict a discrete label.
#
# Let's predict the median price of homes in a Boston suburb in the mid-1970s. We'll provide the model with some data points about the suburb, such as the crime rate and the local property tax rate.

# %%
from __future__ import absolute_import, division, print_function

import tensorflow as tf
from tensorflow import keras

import numpy as np

print(tf.__version__)
# Out:
# 2.1.0

# %% [markdown]
# ## The Boston Housing Prices dataset
#
# The [dataset](https://www.cs.toronto.edu/~delve/data/boston/bostonDetail.html) is accessible directly in TensorFlow.
#
# Let's download and **shuffle** the training set:

# %%
boston_housing = keras.datasets.boston_housing

(train_data, train_labels), (test_data, test_labels) = boston_housing.load_data()

# Shuffle the training set
order = np.argsort(np.random.random(train_labels.shape))
train_data = train_data[order]
train_labels = train_labels[order]

# %%
train_data
# Out:
# array([[7.87500e-02, 4.50000e+01, 3.44000e+00, ..., 1.52000e+01,
#         3.93870e+02, 6.68000e+00],
#        [4.55587e+00, 0.00000e+00, 1.81000e+01, ..., 2.02000e+01,
#         3.54700e+02, 7.12000e+00],
#        [9.60400e-02, 4.00000e+01, 6.41000e+00, ..., 1.76000e+01,
#         3.96900e+02, 2.98000e+00],
#        ...,
#        [4.07710e-01, 0.00000e+00, 6.20000e+00, ..., 1.74000e+01,
#         3.95240e+02, 2.14600e+01],
#        [6.66400e-02, 0.00000e+00, 4.05000e+00, ..., 1.66000e+01,
#         3.90960e+02, 5.33000e+00],
#        [7.02259e+00, 0.00000e+00, 1.81000e+01, ..., 2.02000e+01,
#         3.19980e+02, 1.57000e+01]])

# %% [markdown]
# ### Examples and features
#
# This dataset is small: it has 506 total examples, split between 404 training examples and 102 test examples:

# %%
print("Training set: {}".format(train_data.shape))  # 404 examples, 13 features
print("Testing set:  {}".format(test_data.shape))   # 102 examples, 13 features
# Out:
# Training set: (404, 13)
# Testing set:  (102, 13)

# %% [markdown]
# The dataset contains 13 different features:
#
# 1.   Per capita crime rate.
# 2.   The proportion of residential land zoned for lots over 25,000 square feet.
# 3.   The proportion of non-retail business acres per town.
# 4.   Charles River dummy variable (= 1 if tract bounds river; 0 otherwise).
# 5.   Nitric oxides concentration (parts per 10 million).
# 6.   The average number of rooms per dwelling.
# 7.   The proportion of owner-occupied units built before 1940.
# 8.   Weighted distances to five Boston employment centers.
# 9.   Index of accessibility to radial highways.
# 10.  Full-value property-tax rate per $10,000.
# 11.  Pupil-teacher ratio by town.
# 12.  1000 * (Bk - 0.63) ** 2 where Bk is the proportion of Black people by town.
# 13.  Percentage lower status of the population.
#
# Each one of these input data features is stored using a different scale. Some features are represented by a proportion between 0 and 1, other features are ranges between 1 and 12, some are ranges between 0 and 100, and so on. This is often the case with real-world data, and understanding how to explore and clean such data is an important skill to develop.
#
# > **DISCUSSION**: As a modeler and developer, think about how this data is used and the potential benefits and harm a model's predictions can cause. A model like this could reinforce societal biases and disparities. Is a feature relevant to the problem you want to solve or will it introduce bias? For more information, read about [ML fairness](https://developers.google.com/machine-learning/fairness-overview/).
#
# Let's display sample features and notice the different scales:

# %%
print(train_data[0])
# Out:
# [7.8750e-02 4.5000e+01 3.4400e+00 0.0000e+00 4.3700e-01 6.7820e+00
#  4.1100e+01 3.7886e+00 5.0000e+00 3.9800e+02 1.5200e+01 3.9387e+02
#  6.6800e+00]

# %% [markdown]
# Let's use [pandas](https://pandas.pydata.org) to display the first few rows of the dataset in a nicely formatted table:

# %%
import pandas as pd

column_names = ['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD',
                'TAX', 'PTRATIO', 'B', 'LSTAT']

df = pd.DataFrame(train_data, columns=column_names)
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS   RAD    TAX  \
# 0  0.07875  45.0   3.44   0.0  0.437  6.782  41.1  3.7886   5.0  398.0
# 1  4.55587   0.0  18.10   0.0  0.718  3.561  87.9  1.6132  24.0  666.0
# 2  0.09604  40.0   6.41   0.0  0.447  6.854  42.8  4.2673   4.0  254.0
# 3  0.01870  85.0   4.15   0.0  0.429  6.516  27.7  8.5353   4.0  351.0
# 4  0.52693   0.0   6.20   0.0  0.504  8.725  83.0  2.8944   8.0  307.0
#
#    PTRATIO       B  LSTAT
# 0     15.2  393.87   6.68
# 1     20.2  354.70   7.12
# 2     17.6  396.90   2.98
# 3     17.9  392.43   6.36
# 4     17.4  382.00   4.63

# %% [markdown]
# ### Labels
#
# The labels are the house prices in thousands of dollars. (You may notice mid-1970s prices.)

# %%
train_labels
# Out:
# array([32. , 27.5, 32. , 23.1, 50. , 20.6, 22.6, 36.2, 21.8, 19.5, 15. ,
#        15.6, 50. , 30.1, 12.5, 22.2, 26.5, 50. ,  8.3, 16.5, 17.8, 15.7,
#        19.3, 26.6, 29. , 15.6, 18.7, 24.1, 13.3,  8.5, 19.5, 13.1, 11.7,
#        25. , 24.8, 20.6, 12.1, 19.6, 25. , 22.7, 14.6, 17.1, 50. , 22.6,
#        13.1, 20.6, 18.4, 24.8, 25. , 18.1, 16.8, 16.1, 24.4, 18.5, 21. ,
#        19.1, 16.1, 18.2, 15.3, 20.4, 17.8, 23. ,  7.2, 16.7, 33.4, 13.8,
#        43.8, 28.6, 18.3, 18.7, 17.3, 19.4, 11.9, 20.6, 23.7, 50. , 22.6,
#        25.3, 24.8, 18.7, 21.7, 20.6, 23.2, 26.4, 33.2, 15.2, 41.3, 23.9,
#        31. , 13.4, 23.9, 14.9, 22.8, 28. , 20.4, 12.8, 20.6, 21.4, 14.8,
#        15.6, 30.1, 11. , 25. , 11.7, 16.3, 33.4, 22.9, 29.1, 21. , 31.1,
#        19.3, 23.4, 28.7, 16. , 23.2, 17.2, 26.6, 17.8, 22.3, 20.8, 25.2,
#        28.5, 23.3, 20.1, 19.3, 19.4, 12.7, 37.3, 13.9, 19.6, 12.7, 15.6,
#        32.2, 12.6,  7.5, 23.7, 22.8, 22.2, 44.8, 36.5, 31.6, 22.9, 14.4,
#        14.3,  5. , 19.1, 22.5, 10.9, 23. , 21.4,  8.8, 17.9, 17.5, 11.9,
#        19.3,  8.5, 12.7, 41.7, 19.6, 17.4, 21.4, 23.1, 28.2, 18.2, 16.5,
#        26.2, 13.6, 22.5, 24.4, 18. , 20. , 19.9, 14.9, 50. , 20. , 23.1,
#        13.4,  8.4, 19.4, 50. , 23.9, 22. , 12.3, 27.9, 20.4, 20.4, 33.3,
#        22. , 24.6, 13.3, 14.6, 33.2, 18.5, 24.7, 19.8, 19.4, 24.7, 19.5,
#        22. , 16.2, 45.4, 13.5, 17.1, 22.4, 22. , 15.2, 14.9, 25. , 28.7,
#        16.8, 29.9, 32.7, 21.1, 21.7, 22.1, 11.8, 11.8, 11.5, 22.2, 33.1,
#        10.9, 48.3, 50. , 22.5, 13.3, 23.1, 19.2, 43.5, 29.1, 20.2, 23.9,
#         5. ,  7. , 22.8, 29. , 11.3, 24. , 23.3, 21.7, 10.4, 50. , 16.4,
#        24.4, 21.2, 42.3,  8.3, 14. , 17.8, 23.7, 23.1,  8.4, 22.9, 21.6,
#        13.9, 18.4, 23.6, 20.1, 15.6, 20.5, 14.5, 17.4, 23. , 50. , 19.1,
#        19.7, 34.7, 21. , 27.9, 24.5, 21.4, 24.8, 22.2, 18.4, 16.1, 10.5,
#        30.5, 13.5, 34.9, 21.9, 31.5, 19.5, 19.2, 17.1, 24. , 13.8, 20.8,
#        21.2, 18.9,  8.7, 10.2, 19.9, 13.1, 28.7, 23.8, 20.3, 17.2, 29.8,
#        19.7, 34.6, 14.3, 46. , 30.8, 18.8, 35.2, 48.8, 37.9, 18.3,  8.8,
#        17. , 39.8, 31.7, 19.4, 15. , 18.2, 13.8, 23.8, 24.7, 13.8, 50. ,
#        23.3, 24.3, 24.4, 10.4, 33.8, 38.7, 30.7, 25.1, 23.7, 48.5, 20.3,
#        13.4, 15.2, 17.4, 19.6, 18.9, 15. , 23.9, 37.6, 36.2, 14.1, 17.2,
#        22.6, 20.5,  6.3, 21.2, 31.5, 22.6, 21.1, 13.8, 20.7, 24.1,  9.6,
#        10.5, 44. , 13.6, 32.9, 13.4, 23.3, 23.6, 37. , 19.3, 50. , 23.5,
#        18.9, 17.5, 19.4, 20.1, 37.2, 19.9, 21.7, 30.3, 23.1, 36.1, 24.6,
#        22. , 23.8, 16.7, 20.3, 18.5, 13.2, 50. , 36.4, 16.6, 21.7, 17.5,
#        34.9, 22.8, 27.1, 22.3, 17.7, 19.9, 20.7, 10.8, 20. , 27.5, 21.8,
#        31.6, 20. , 14.4, 15.1, 19. , 21.7, 29.4, 14.2])

# %%
print(train_labels[0:10])  # Display first 10 entries
# Out:
# [32.  27.5 32.  23.1 50.  20.6 22.6 36.2 21.8 19.5]

# %% [markdown]
# ## Normalize features
#
# It's ***always*** recommended to normalize features that use different scales and ranges.
#
# For each feature, subtract the mean of the feature and divide by the standard deviation (or use `sklearn`'s `preprocessing.MinMaxScaler` API):

# %%
# Test data is *not* used when calculating the mean and std

mean = train_data.mean(axis=0)
std = train_data.std(axis=0)
train_data = (train_data - mean) / std
test_data = (test_data - mean) / std

print(train_data[0])  # First training sample, normalized
# Out:
# [-0.39725269  1.41205707 -1.12664623 -0.25683275 -1.027385    0.72635358
#  -1.00016413  0.02383449 -0.51114231 -0.04753316 -1.49067405  0.41584124
#  -0.83648691]

# %% [markdown]
# Although the model *might* converge without feature normalization, it makes training more ***difficult***, and it makes the resulting model more dependent on the choice of units used in the input.

# %% [markdown]
# ## Create the model
#
# Let's build our model. Here, we'll use a Keras `Sequential` model with two densely connected hidden layers (since these worked so well for us in the noisy sine), and an output layer that returns a **single**, **continuous** value. The model building steps are wrapped in a function, `build_model`, since we'll create a second model, later on.
#
# `model.summary()`gives us a nice visual:

# %%
def build_model():
  model = keras.Sequential([
    keras.layers.Dense(64, activation=tf.nn.relu,
                       input_shape=(train_data.shape[1],)),
    keras.layers.Dense(64, activation=tf.nn.relu),
    keras.layers.Dense(1)
  ])

  optimizer = tf.compat.v1.train.RMSPropOptimizer(0.001)

  model.compile(loss='mse',
                optimizer=optimizer,
                metrics=['mae'])
  return model

model = build_model()
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_3 (Dense)              (None, 64)                896
# _________________________________________________________________
# dense_4 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 5,121
# Trainable params: 5,121
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Train the model
#
# Let's train for 500 epochs and record the training and validation accuracy in the `history2` object.

# %%
type(train_data)
# Out:
# numpy.ndarray

# %%
type(train_labels)
# Out:
# numpy.ndarray

# %%
# Display training progress by printing a single dot for each completed epoch
class PrintDot(keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs):
    if epoch % 100 == 0: print('')
    print('.', end='')

EPOCHS = 500

# Store training stats
history2 = model.fit(train_data, train_labels, epochs=EPOCHS,
                    validation_split=0.2, verbose=0,
                    callbacks=[PrintDot()])
# Out:
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................

# %% [markdown]
# Let's visualize the model's training progress using the stats stored in the `history` object. We want to use this data to determine how long to train *before* the model stops making progress.

# %%
import matplotlib.pyplot as plt


def plot_history(history):
  plt.figure()
  plt.xlabel('Epoch')
  plt.ylabel('Mean Abs Error [1000$]')
  plt.plot(history.epoch, np.array(history.history['mean_absolute_error']),
           label='Train Loss')
  plt.plot(history.epoch, np.array(history.history['val_mean_absolute_error']),
           label = 'Val loss')
  plt.legend()
  plt.ylim([0, 5])

plot_history(history2)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-23-2dcd5ffb425f> in <module>
#      13   plt.ylim([0, 5])
#      14
# ---> 15 plot_history(history2)
#
# <ipython-input-23-2dcd5ffb425f> in plot_history(history)
#       6   plt.xlabel('Epoch')
#       7   plt.ylabel('Mean Abs Error [1000$]')
# ----> 8   plt.plot(history.epoch, np.array(history.history['mean_absolute_error']),
#       9            label='Train Loss')
#      10   plt.plot(history.epoch, np.array(history.history['val_mean_absolute_error']),
#
# KeyError: 'mean_absolute_error'

# %% [markdown]
# This graph shows little improvement in the model after about 200 epochs. Let's update the `model.fit` method to automatically **stop training** when the validation score doesn't improve. We'll use a *callback* that tests a training condition for  every epoch. If a set amount of epochs elapses without showing improvement, then automatically stop the training.
#
# You can learn more about this callback [here](https://www.tensorflow.org/versions/master/api_docs/python/tf/keras/callbacks/EarlyStopping).

# %%
model = build_model()

# The patience parameter is the amount of epochs to check for improvement
early_stop = keras.callbacks.EarlyStopping(monitor='val_loss', patience=20)

history2 = model.fit(train_data, train_labels, epochs=EPOCHS,
                    validation_split=0.2, verbose=0,
                    callbacks=[early_stop, PrintDot()])

plot_history(history2)
# Out:
# ....................................................................................................
# ..
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-24-593ae362fb77> in <module>
#       8                     callbacks=[early_stop, PrintDot()])
#       9
# ---> 10 plot_history(history2)
#
# <ipython-input-23-2dcd5ffb425f> in plot_history(history)
#       6   plt.xlabel('Epoch')
#       7   plt.ylabel('Mean Abs Error [1000$]')
# ----> 8   plt.plot(history.epoch, np.array(history.history['mean_absolute_error']),
#       9            label='Train Loss')
#      10   plt.plot(history.epoch, np.array(history.history['val_mean_absolute_error']),
#
# KeyError: 'mean_absolute_error'

# %% [markdown]
# The graph shows the average error is about \\$2,500 dollars.
#
# Let's see how did the model performs on the test set:

# %%
[loss, mae] = model.evaluate(test_data, test_labels, verbose=0)

print("Testing set Mean Abs Error: ${:7.2f}".format(mae * 1000))
# Out:
# Testing set Mean Abs Error: $2979.11

# %% [markdown]
# ## Predict
#
# Finally, let's predict some housing prices using data in the testing set:

# %%
test_predictions = model.predict(test_data).flatten()

plt.scatter(test_labels, test_predictions)
plt.xlabel('True Values [1000$]')
plt.ylabel('Predictions [1000$]')
plt.axis('equal')
plt.xlim(plt.xlim())
plt.ylim(plt.ylim())
_ = plt.plot([-100, 100], [-100, 100])

# %%
error = test_predictions - test_labels
plt.hist(error, bins = 50)
plt.xlabel("Prediction Error [1000$]")
_ = plt.ylabel("Count")

# %% [markdown]
# What does this histogram look like?
#
# ## Some advice, not nearly enough
#
# * Mean Squared Error (MSE) is a common loss function used for regression problems (different than classification problems).
# * Similarly, evaluation metrics used for regression differ from classification. A common regression metric is Mean Absolute Error (MAE).
# * When input data features have values with different ranges, each feature should be scaled independently.
# * If there is not much training data, prefer a small network with few hidden layers to avoid overfitting.
# * Early stopping is a useful technique to prevent overfitting.
